# %% [markdown]
# # CitiBike Data Analysis
#
# ## Summary: The purpose of this analysis is to assess which station in NYC's bike share system is the most active. Specfically, the aim is to record the number of bikes incoming and outgoing in every station across the city for 1 hour. Activity was defined as bikes in + bikes out. The station with the highest activity score was determined to be the most active.

# %%
import requests # package that allows us to download data from any online resource
import json

# %%
# to access the URL
r = requests.get('https://feeds.citibikenyc.com/stations/stations.json')

# %%
r.text # basic view of the raw data--it needs some formatting to be in proper form for analysis
# Out:
# '{"executionTime":"2017-01-30 08:13:36 PM","stationBeanList":[{"id":72,"stationName":"W 52 St & 11 Ave","availableDocks":34,"totalDocks":39,"latitude":40.76727216,"longitude":-73.99392888,"statusValue":"In Service","statusKey":1,"availableBikes":5,"stAddress1":"W 52 St & 11 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:13:32 PM","landMark":""},{"id":79,"stationName":"Franklin St & W Broadway","availableDocks":9,"totalDocks":33,"latitude":40.71911552,"longitude":-74.00666661,"statusValue":"In Service","statusKey":1,"availableBikes":24,"stAddress1":"Franklin St & W Broadway","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:12:25 PM","landMark":""},{"id":82,"stationName":"St James Pl & Pearl St","availableDocks":25,"totalDocks":27,"latitude":40.71117416,"longitude":-74.00016545,"statusValue":"In Service","statusKey":1,"availableBikes":2,"stAddress1":"St James Pl & Pearl St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:10:07 PM","landMark":""},{"id":83,"stationName":"Atlantic Ave & Fort Greene Pl","availableDocks":51,"totalDocks":62,"latitude":40.68382604,"longitude":-73.97632328,"statusValue":"In Service","statusKey":1,"availableBikes":9,"stAddress1":"Atlantic Ave & Fort Greene Pl","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:11:06 PM","landMark":""},{"id":116,"stationName":"W 17 St & 8 Ave","availableDocks":31,"totalDocks":39,"latitude":40.74177603,"longitude":-74.00149746,"statusValue":"In Service","statusKey":1,"availableBikes":7,"stAddress1":"W 17 St & 8 Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:10:01 PM","landMark":""},{"id":119,"stationName":"Park Ave & St Edwards St","availableDocks":7,"totalDocks":19,"latitude":40.69608941,"longitude":-73.97803415,"statusValue":"In Service","statusKey":1,"availableBikes":12,"stAddress1":"Park Ave & St Edwards St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:12:57 PM","landMark":""},{"id":120,"stationName":"Lexington Ave & Classon Ave","availableDocks":13,"totalDocks":19,"latitude":40.68676793,"longitude":-73.95928168,"statusValue":"In Service","statusKey":1,"availableBikes":6,"stAddress1":"Lexington Ave & Classon Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:13:04 PM","landMark":""},{"id":127,"stationName":"Barrow St & Hudson St","availableDocks":9,"totalDocks":31,"latitude":40.73172428,"longitude":-74.00674436,"statusValue":"In Service","statusKey":1,"availableBikes":20,"stAddress1":"Barrow St & Hudson St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:12:52 PM","landMark":""},{"id":128,"stationName":"MacDougal St & Prince St","availableDocks":16,"totalDocks":30,"latitude":40.72710258,"longitude":-74.00297088,"statusValue":"In Service","statusKey":1,"availableBikes":13,"stAddress1":"MacDougal St & Prince St","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"2017-01-30 08:13:17 PM","landMark":""},{"id":137,"stationName":"E 56 St & Madison Ave","availableDocks":0,"totalDocks":0,"latitude":40.761628,"longitude":-73.972924,"statusValue":"Not In Service","statusKey":3,"availableBikes":0,"stAddress1":"E 56 St & Madison Ave","stAddress2":"","city":"","postalCode":"","location":"","altitude":"","testStation":false,"lastCommunicationTime":"1969-12-31 07:00:00 PM","landMark":""},{"id":143,"stationName":"Clinton St & Joralemon St","availableDocks":21,"totalDocks":24 ...

# %%
# json function will make the text easier to read
r.json() #now, data is formatted into a javascript object notation(json).
# Out:
# {'executionTime': '2017-01-30 08:13:36 PM',
#  'stationBeanList': [{'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 34,
#    'city': '',
#    'id': 72,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:32 PM',
#    'latitude': 40.76727216,
#    'location': '',
#    'longitude': -73.99392888,
#    'postalCode': '',
#    'stAddress1': 'W 52 St & 11 Ave',
#    'stAddress2': '',
#    'stationName': 'W 52 St & 11 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 24,
#    'availableDocks': 9,
#    'city': '',
#    'id': 79,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:25 PM',
#    'latitude': 40.71911552,
#    'location': '',
#    'longitude': -74.00666661,
#    'postalCode': '',
#    'stAddress1': 'Franklin St & W Broadway',
#    'stAddress2': '',
#    'stationName': 'Franklin St & W Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 25,
#    'city': '',
#    'id': 82,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:07 PM',
#    'latitude': 40.71117416,
#    'location': '',
#    'longitude': -74.00016545,
#    'postalCode': '',
#    'stAddress1': 'St James Pl & Pearl St',
#    'stAddress2': '',
#    'stationName': 'St James Pl & Pearl St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 51,
#    'city': '',
#    'id': 83,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:06 PM',
#    'latitude': 40.68382604,
#    'location': '',
#    'longitude': -73.97632328,
#    'postalCode': '',
#    'stAddress1': 'Atlantic Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'stationName': 'Atlantic Ave & Fort Greene Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 62},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 31,
#    'city': '',
#    'id': 116,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:01 PM',
#    'latitude': 40.74177603,
#    'location': '',
#    'longitude': -74.00149746,
#    'postalCode': '',
#    'stAddress1': 'W 17 St & 8 Ave',
#    'stAddress2': '',
#    'stationName': 'W 17 St & 8 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 7,
#    'city': '',
#    'id': 119,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:57 PM',
#    'latitude': 40.69608941,
#    'location': '',
#    'longitude': -73.97803415,
#    'postalCode': '',
#    'stAddress1': 'Park Ave & St Edwards St',
#    'stAddress2': '',
#    'stationName': 'Park Ave & St Edwards St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 13,
#    'city': '',
#    'id': 120,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#    'latitude': 40.68676793,
#    'location': '',
#    'longitude': -73.95928168,
#    'postalCode': '',
#    'stAddress1': 'Lexington Ave & Classon Ave',
#    'stAddress2': '',
#    'stationName': 'Lexington Ave & Classon Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 20,
#    'availableDocks': 9,
#    'city': '',
#    'id': 127,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:52 PM',
#    'latitude': 40.73172428,
#    'location': '',
#    'longitude': -74.00674436,
#    'postalCode': '',
#    'stAddress1': 'Barrow St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Barrow St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 16,
#    'city': '',
#    'id': 128,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:17 PM',
#    'latitude': 40.72710258,
#    'location': '',
#    'longitude': -74.00297088,
#    'postalCode': '',
#    'stAddress1': 'MacDougal St & Prince St',
#    'stAddress2': '',
#    'stationName': 'MacDougal St & Prince St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 137,
#    'landMark': '',
#    'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#    'latitude': 40.761628,
#    'location': '',
#    'longitude': -73.972924,
#    'postalCode': '',
#    'stAddress1': 'E 56 St & Madison Ave',
#    'stAddress2': '',
#    'stationName': 'E 56 St & Madison Ave',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 0},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 21,
#    'city': '',
#    'id': 143,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:45 PM',
#    'latitude': 40.69239502,
#    'location': '',
#    'longitude': -73.99337909,
#    'postalCode': '',
#    'stAddress1': 'Clinton St & Joralemon St',
#    'stAddress2': '',
#    'stationName': 'Clinton St & Joralemon St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 9,
#    'city': '',
#    'id': 144,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:53 PM',
#    'latitude': 40.69839895,
#    'location': '',
#    'longitude': -73.98068914,
#    'postalCode': '',
#    'stAddress1': 'Nassau St & Navy St',
#    'stAddress2': '',
#    'stationName': 'Nassau St & Navy St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 33,
#    'availableDocks': 6,
#    'city': '',
#    'id': 146,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:15 PM',
#    'latitude': 40.71625008,
#    'location': '',
#    'longitude': -74.0091059,
#    'postalCode': '',
#    'stAddress1': 'Hudson St & Reade St',
#    'stAddress2': '',
#    'stationName': 'Hudson St & Reade St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 31,
#    'availableDocks': 2,
#    'city': '',
#    'id': 147,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:33 PM',
#    'latitude': 40.71542197,
#    'location': '',
#    'longitude': -74.01121978,
#    'postalCode': '',
#    'stAddress1': 'Greenwich St & Warren St',
#    'stAddress2': '',
#    'stationName': 'Greenwich St & Warren St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 18,
#    'city': '',
#    'id': 150,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:13 PM',
#    'latitude': 40.7208736,
#    'location': '',
#    'longitude': -73.98085795,
#    'postalCode': '',
#    'stAddress1': 'E 2 St & Avenue C',
#    'stAddress2': '',
#    'stationName': 'E 2 St & Avenue C',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 30,
#    'city': '',
#    'id': 151,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#    'latitude': 40.722103786686034,
#    'location': '',
#    'longitude': -73.99724900722504,
#    'postalCode': '',
#    'stAddress1': 'Cleveland Pl & Spring St',
#    'stAddress2': '',
#    'stationName': 'Cleveland Pl & Spring St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 4,
#    'city': '',
#    'id': 152,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:47 PM',
#    'latitude': 40.71473993,
#    'location': '',
#    'longitude': -74.00910627,
#    'postalCode': '',
#    'stAddress1': 'Warren St & Church St',
#    'stAddress2': '',
#    'stationName': 'Warren St & Church St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 54,
#    'city': '',
#    'id': 153,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:50 PM',
#    'latitude': 40.752062307,
#    'location': '',
#    'longitude': -73.9816324043,
#    'postalCode': '',
#    'stAddress1': 'E 40 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'E 40 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 16,
#    'city': '',
#    'id': 157,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:26 PM',
#    'latitude': 40.69089272,
#    'location': '',
#    'longitude': -73.99612349,
#    'postalCode': '',
#    'stAddress1': 'Henry St & Atlantic Ave',
#    'stAddress2': '',
#    'stationName': 'Henry St & Atlantic Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 32,
#    'availableDocks': 3,
#    'city': '',
#    'id': 161,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:39 PM',
#    'latitude': 40.72917025,
#    'location': '',
#    'longitude': -73.99810231,
#    'postalCode': '',
#    'stAddress1': 'LaGuardia Pl & W 3 St',
#    'stAddress2': '',
#    'stationName': 'LaGuardia Pl & W 3 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 38,
#    'city': '',
#    'id': 164,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:33 PM',
#    'latitude': 40.75323098,
#    'location': '',
#    'longitude': -73.97032517,
#    'postalCode': '',
#    'stAddress1': 'E 47 St & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'E 47 St & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 47},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 44,
#    'city': '',
#    'id': 167,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:51 PM',
#    'latitude': 40.7489006,
#    'location': '',
#    'longitude': -73.97604882,
#    'postalCode': '',
#    'stAddress1': 'E 39 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 39 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 45},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 42,
#    'city': '',
#    'id': 168,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:04 PM',
#    'latitude': 40.73971301,
#    'location': '',
#    'longitude': -73.99456405,
#    'postalCode': '',
#    'stAddress1': 'W 18 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'W 18 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 47},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 49,
#    'city': '',
#    'id': 173,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:52 PM',
#    'latitude': 40.76068327096592,
#    'location': '',
#    'longitude': -73.9845272898674,
#    'postalCode': '',
#    'stAddress1': 'Broadway & W 49 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & W 49 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 51},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 20,
#    'city': '',
#    'id': 174,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:08 PM',
#    'latitude': 40.7381765,
#    'location': '',
#    'longitude': -73.97738662,
#    'postalCode': '',
#    'stAddress1': 'E 25 St & 1 Ave',
#    'stAddress2': '',
#    'stationName': 'E 25 St & 1 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 30},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 43,
#    'city': '',
#    'id': 195,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:26 PM',
#    'latitude': 40.70905623,
#    'location': '',
#    'longitude': -74.01043382,
#    'postalCode': '',
#    'stAddress1': 'Liberty St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Liberty St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 45},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 25,
#    'city': '',
#    'id': 212,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:09 PM',
#    'latitude': 40.74334935,
#    'location': '',
#    'longitude': -74.00681753,
#    'postalCode': '',
#    'stAddress1': 'W 16 St & The High Line',
#    'stAddress2': '',
#    'stationName': 'W 16 St & The High Line',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 28},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 21,
#    'city': '',
#    'id': 216,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:03 PM',
#    'latitude': 40.70037867,
#    'location': '',
#    'longitude': -73.99548059,
#    'postalCode': '',
#    'stAddress1': 'Columbia Heights & Cranberry St',
#    'stAddress2': '',
#    'stationName': 'Columbia Heights & Cranberry St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 17,
#    'city': '',
#    'id': 217,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:45 PM',
#    'latitude': 40.70277159,
#    'location': '',
#    'longitude': -73.99383605,
#    'postalCode': '',
#    'stAddress1': 'Old Fulton St',
#    'stAddress2': '',
#    'stationName': 'Old Fulton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 3,
#    'city': '',
#    'id': 223,
#    'landMark': '',
#    'lastCommunicationTime': '2016-11-22 07:39:47 AM',
#    'latitude': 40.73781509,
#    'location': '',
#    'longitude': -73.99994661,
#    'postalCode': '',
#    'stAddress1': 'W 13 St & 7 Ave',
#    'stAddress2': '',
#    'stationName': 'W 13 St & 7 Ave',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 3},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 29,
#    'city': '',
#    'id': 224,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:20 PM',
#    'latitude': 40.71146364,
#    'location': '',
#    'longitude': -74.00552427,
#    'postalCode': '',
#    'stAddress1': 'Spruce St & Nassau St',
#    'stAddress2': '',
#    'stationName': 'Spruce St & Nassau St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 20,
#    'availableDocks': 15,
#    'city': '',
#    'id': 225,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:12 PM',
#    'latitude': 40.74195138,
#    'location': '',
#    'longitude': -74.00803013,
#    'postalCode': '',
#    'stAddress1': 'W 14 St & The High Line',
#    'stAddress2': '',
#    'stationName': 'W 14 St & The High Line',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 37},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 54,
#    'city': '',
#    'id': 228,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:35 PM',
#    'latitude': 40.7546011026,
#    'location': '',
#    'longitude': -73.971878855,
#    'postalCode': '',
#    'stAddress1': 'E 48 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 48 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 7,
#    'city': '',
#    'id': 229,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:54 PM',
#    'latitude': 40.72743423,
#    'location': '',
#    'longitude': -73.99379025,
#    'postalCode': '',
#    'stAddress1': 'Great Jones St',
#    'stAddress2': '',
#    'stationName': 'Great Jones St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 13,
#    'city': '',
#    'id': 232,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:05 PM',
#    'latitude': 40.69597683,
#    'location': '',
#    'longitude': -73.99014892,
#    'postalCode': '',
#    'stAddress1': 'Cadman Plaza E & Tillary St',
#    'stAddress2': '',
#    'stationName': 'Cadman Plaza E & Tillary St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 27,
#    'availableDocks': 12,
#    'city': '',
#    'id': 236,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:24 PM',
#    'latitude': 40.7284186,
#    'location': '',
#    'longitude': -73.98713956,
#    'postalCode': '',
#    'stAddress1': 'St Marks Pl & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'St Marks Pl & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 12,
#    'city': '',
#    'id': 237,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:44 PM',
#    'latitude': 40.73047309,
#    'location': '',
#    'longitude': -73.98672378,
#    'postalCode': '',
#    'stAddress1': 'E 11 St & 2 Ave',
#    'stAddress2': '',
#    'stationName': 'E 11 St & 2 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 17,
#    'availableDocks': 14,
#    'city': '',
#    'id': 238,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:16 PM',
#    'latitude': 40.7361967,
#    'location': '',
#    'longitude': -74.00859207,
#    'postalCode': '',
#    'stAddress1': 'Bank St & Washington St',
#    'stAddress2': '',
#    'stationName': 'Bank St & Washington St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 31,
#    'city': '',
#    'id': 239,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#    'latitude': 40.69196566,
#    'location': '',
#    'longitude': -73.9813018,
#    'postalCode': '',
#    'stAddress1': 'Willoughby St & Fleet St',
#    'stAddress2': '',
#    'stationName': 'Willoughby St & Fleet St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 16,
#    'city': '',
#    'id': 241,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:46 PM',
#    'latitude': 40.68981035,
#    'location': '',
#    'longitude': -73.97493121,
#    'postalCode': '',
#    'stAddress1': 'DeKalb Ave & S Portland Ave',
#    'stAddress2': '',
#    'stationName': 'DeKalb Ave & S Portland Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 16,
#    'availableDocks': 7,
#    'city': '',
#    'id': 242,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:21 PM',
#    'latitude': 40.697787,
#    'location': '',
#    'longitude': -73.973736,
#    'postalCode': '',
#    'stAddress1': 'Carlton Ave & Flushing Ave',
#    'stAddress2': '',
#    'stationName': 'Carlton Ave & Flushing Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 19,
#    'availableDocks': 12,
#    'city': '',
#    'id': 243,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:44 PM',
#    'latitude': 40.688226,
#    'location': '',
#    'longitude': -73.979382,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Rockwell Pl',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Rockwell Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 21,
#    'city': '',
#    'id': 244,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:37 PM',
#    'latitude': 40.69196035,
#    'location': '',
#    'longitude': -73.96536851,
#    'postalCode': '',
#    'stAddress1': 'Willoughby Ave & Hall St',
#    'stAddress2': '',
#    'stationName': 'Willoughby Ave & Hall St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 23,
#    'city': '',
#    'id': 245,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:31 PM',
#    'latitude': 40.69327018,
#    'location': '',
#    'longitude': -73.97703874,
#    'postalCode': '',
#    'stAddress1': 'Myrtle Ave & St Edwards St',
#    'stAddress2': '',
#    'stationName': 'Myrtle Ave & St Edwards St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 6,
#    'city': '',
#    'id': 247,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:02 PM',
#    'latitude': 40.73535398,
#    'location': '',
#    'longitude': -74.00483091,
#    'postalCode': '',
#    'stAddress1': 'Perry St & Bleecker St',
#    'stAddress2': '',
#    'stationName': 'Perry St & Bleecker St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 20},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 17,
#    'city': '',
#    'id': 248,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:22 PM',
#    'latitude': 40.72185379,
#    'location': '',
#    'longitude': -74.00771779,
#    'postalCode': '',
#    'stAddress1': 'Laight St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Laight St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 15,
#    'city': '',
#    'id': 249,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:22 PM',
#    'latitude': 40.71870987,
#    'location': '',
#    'longitude': -74.0090009,
#    'postalCode': '',
#    'stAddress1': 'Harrison St & Hudson St',
#    'stAddress2': '',
#    'stationName': 'Harrison St & Hudson St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 19,
#    'availableDocks': 7,
#    'city': '',
#    'id': 251,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:07 PM',
#    'latitude': 40.72317958,
#    'location': '',
#    'longitude': -73.99480012,
#    'postalCode': '',
#    'stAddress1': 'Mott St & Prince St',
#    'stAddress2': '',
#    'stationName': 'Mott St & Prince St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 33,
#    'availableDocks': 0,
#    'city': '',
#    'id': 252,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:30 PM',
#    'latitude': 40.73226398,
#    'location': '',
#    'longitude': -73.99852205,
#    'postalCode': '',
#    'stAddress1': 'MacDougal St & Washington Sq',
#    'stAddress2': '',
#    'stationName': 'MacDougal St & Washington Sq',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 43,
#    'availableDocks': 10,
#    'city': '',
#    'id': 253,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:19 PM',
#    'latitude': 40.73543934,
#    'location': '',
#    'longitude': -73.99453948,
#    'postalCode': '',
#    'stAddress1': 'W 13 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'W 13 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 20,
#    'availableDocks': 9,
#    'city': '',
#    'id': 254,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:00 PM',
#    'latitude': 40.73532427,
#    'location': '',
#    'longitude': -73.99800419,
#    'postalCode': '',
#    'stAddress1': 'W 11 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'W 11 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 17,
#    'city': '',
#    'id': 257,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:57 PM',
#    'latitude': 40.71939226,
#    'location': '',
#    'longitude': -74.00247214,
#    'postalCode': '',
#    'stAddress1': 'Lispenard St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Lispenard St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 12,
#    'city': '',
#    'id': 258,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#    'latitude': 40.68940747,
#    'location': '',
#    'longitude': -73.96885458,
#    'postalCode': '',
#    'stAddress1': 'DeKalb Ave & Vanderbilt Ave',
#    'stAddress2': '',
#    'stationName': 'DeKalb Ave & Vanderbilt Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 11,
#    'city': '',
#    'id': 259,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:18 PM',
#    'latitude': 40.70122128,
#    'location': '',
#    'longitude': -74.01234218,
#    'postalCode': '',
#    'stAddress1': 'South St & Whitehall St',
#    'stAddress2': '',
#    'stationName': 'South St & Whitehall St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 18,
#    'availableDocks': 16,
#    'city': '',
#    'id': 260,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:07 PM',
#    'latitude': 40.70365182,
#    'location': '',
#    'longitude': -74.01167797,
#    'postalCode': '',
#    'stAddress1': 'Broad St & Bridge St',
#    'stAddress2': '',
#    'stationName': 'Broad St & Bridge St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 14,
#    'city': '',
#    'id': 261,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:31 PM',
#    'latitude': 40.69474881,
#    'location': '',
#    'longitude': -73.98362464,
#    'postalCode': '',
#    'stAddress1': 'Johnson St & Gold St',
#    'stAddress2': '',
#    'stationName': 'Johnson St & Gold St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 17,
#    'city': '',
#    'id': 262,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:15 PM',
#    'latitude': 40.6917823,
#    'location': '',
#    'longitude': -73.9737299,
#    'postalCode': '',
#    'stAddress1': 'Washington Park',
#    'stAddress2': '',
#    'stationName': 'Washington Park',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 17,
#    'availableDocks': 9,
#    'city': '',
#    'id': 264,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:49 PM',
#    'latitude': 40.70706456,
#    'location': '',
#    'longitude': -74.00731853,
#    'postalCode': '',
#    'stAddress1': 'Maiden Ln & Pearl St',
#    'stAddress2': '',
#    'stationName': 'Maiden Ln & Pearl St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 30,
#    'city': '',
#    'id': 265,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:49 PM',
#    'latitude': 40.72229346,
#    'location': '',
#    'longitude': -73.99147535,
#    'postalCode': '',
#    'stAddress1': 'Stanton St & Chrystie St',
#    'stAddress2': '',
#    'stationName': 'Stanton St & Chrystie St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 13,
#    'city': '',
#    'id': 266,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:40 PM',
#    'latitude': 40.72368361,
#    'location': '',
#    'longitude': -73.97574813,
#    'postalCode': '',
#    'stAddress1': 'Avenue D & E 8 St',
#    'stAddress2': '',
#    'stationName': 'Avenue D & E 8 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 55,
#    'city': '',
#    'id': 267,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:30 PM',
#    'latitude': 40.75097711,
#    'location': '',
#    'longitude': -73.98765428,
#    'postalCode': '',
#    'stAddress1': 'Broadway & W 36 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & W 36 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 57},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 12,
#    'city': '',
#    'id': 268,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:17 PM',
#    'latitude': 40.71910537,
#    'location': '',
#    'longitude': -73.99973337,
#    'postalCode': '',
#    'stAddress1': 'Howard St & Centre St',
#    'stAddress2': '',
#    'stationName': 'Howard St & Centre St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 9,
#    'city': '',
#    'id': 270,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:01 PM',
#    'latitude': 40.69308257,
#    'location': '',
#    'longitude': -73.97178913,
#    'postalCode': '',
#    'stAddress1': 'Adelphi St & Myrtle Ave',
#    'stAddress2': '',
#    'stationName': 'Adelphi St & Myrtle Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 21,
#    'city': '',
#    'id': 274,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:27 PM',
#    'latitude': 40.68691865,
#    'location': '',
#    'longitude': -73.976682,
#    'postalCode': '',
#    'stAddress1': 'Lafayette Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'stationName': 'Lafayette Ave & Fort Greene Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 14,
#    'city': '',
#    'id': 275,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:04 PM',
#    'latitude': 40.68650065,
#    'location': '',
#    'longitude': -73.96563307,
#    'postalCode': '',
#    'stAddress1': 'Washington Ave & Greene Ave',
#    'stAddress2': '',
#    'stationName': 'Washington Ave & Greene Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 18,
#    'availableDocks': 5,
#    'city': '',
#    'id': 276,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#    'latitude': 40.71748752,
#    'location': '',
#    'longitude': -74.0104554,
#    'postalCode': '',
#    'stAddress1': 'Duane St & Greenwich St',
#    'stAddress2': '',
#    'stationName': 'Duane St & Greenwich St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 13,
#    'city': '',
#    'id': 278,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:39 PM',
#    'latitude': 40.69766564,
#    'location': '',
#    'longitude': -73.98476437,
#    'postalCode': '',
#    'stAddress1': 'Concord St & Bridge St',
#    'stAddress2': '',
#    'stationName': 'Concord St & Bridge St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 33,
#    'city': '',
#    'id': 279,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:09 PM',
#    'latitude': 40.707873,
#    'location': '',
#    'longitude': -74.00167,
#    'postalCode': '',
#    'stAddress1': 'Peck Slip & Front St',
#    'stAddress2': '',
#    'stationName': 'Peck Slip & Front St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 36},
#   {'altitude': '',
#    'availableBikes': 25,
#    'availableDocks': 6,
#    'city': '',
#    'id': 280,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:56 PM',
#    'latitude': 40.73331967,
#    'location': '',
#    'longitude': -73.99510132,
#    'postalCode': '',
#    'stAddress1': 'E 10 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'E 10 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 57,
#    'city': '',
#    'id': 281,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:35 PM',
#    'latitude': 40.7643971,
#    'location': '',
#    'longitude': -73.97371465,
#    'postalCode': '',
#    'stAddress1': 'Grand Army Plaza & Central Park S',
#    'stAddress2': '',
#    'stationName': 'Grand Army Plaza & Central Park S',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 59},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 22,
#    'city': '',
#    'id': 282,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:52 PM',
#    'latitude': 40.707644944175705,
#    'location': '',
#    'longitude': -73.96841526031494,
#    'postalCode': '',
#    'stAddress1': 'Kent Ave & S 11 St',
#    'stAddress2': '',
#    'stationName': 'Kent Ave & S 11 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 34,
#    'availableDocks': 3,
#    'city': '',
#    'id': 284,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:01 PM',
#    'latitude': 40.7390169121,
#    'location': '',
#    'longitude': -74.0026376103,
#    'postalCode': '',
#    'stAddress1': 'Greenwich Ave & 8 Ave',
#    'stAddress2': '',
#    'stationName': 'Greenwich Ave & 8 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 43},
#   {'altitude': '',
#    'availableBikes': 29,
#    'availableDocks': 18,
#    'city': '',
#    'id': 285,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:13 PM',
#    'latitude': 40.73454567,
#    'location': '',
#    'longitude': -73.99074142,
#    'postalCode': '',
#    'stAddress1': 'Broadway & E 14 St',
#    'stAddress2': '',
#    'stationName': 'Broadway & E 14 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 47},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 13,
#    'city': '',
#    'id': 289,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:53 PM',
#    'latitude': 40.6845683,
#    'location': '',
#    'longitude': -73.95881081,
#    'postalCode': '',
#    'stAddress1': 'Monroe St & Classon Ave',
#    'stAddress2': '',
#    'stationName': 'Monroe St & Classon Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 7,
#    'city': '',
#    'id': 291,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:54 PM',
#    'latitude': 40.713126,
#    'location': '',
#    'longitude': -73.984844,
#    'postalCode': '',
#    'stAddress1': 'Madison St & Montgomery St',
#    'stAddress2': '',
#    'stationName': 'Madison St & Montgomery St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 20},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 53,
#    'city': '',
#    'id': 293,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:05 PM',
#    'latitude': 40.73028666,
#    'location': '',
#    'longitude': -73.9907647,
#    'postalCode': '',
#    'stAddress1': 'Lafayette St & E 8 St',
#    'stAddress2': '',
#    'stationName': 'Lafayette St & E 8 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 55},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 24,
#    'city': '',
#    'id': 295,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:14 PM',
#    'latitude': 40.71406667,
#    'location': '',
#    'longitude': -73.99293911,
#    'postalCode': '',
#    'stAddress1': 'Pike St & E Broadway',
#    'stAddress2': '',
#    'stationName': 'Pike St & E Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 24},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 23,
#    'city': '',
#    'id': 296,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:14 PM',
#    'latitude': 40.71413089,
#    'location': '',
#    'longitude': -73.9970468,
#    'postalCode': '',
#    'stAddress1': 'Division St & Bowery',
#    'stAddress2': '',
#    'stationName': 'Division St & Bowery',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 15,
#    'city': '',
#    'id': 297,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:33 PM',
#    'latitude': 40.734232,
#    'location': '',
#    'longitude': -73.986923,
#    'postalCode': '',
#    'stAddress1': 'E 15 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 15 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 298,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-13 09:25:10 AM',
#    'latitude': 40.68683208,
#    'location': '',
#    'longitude': -73.9796772,
#    'postalCode': '',
#    'stAddress1': '3 Ave & Schermerhorn St',
#    'stAddress2': '',
#    'stationName': '3 Ave & Schermerhorn St',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 8},
#   {'altitude': '',
#    'availableBikes': 30,
#    'availableDocks': 4,
#    'city': '',
#    'id': 301,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:03 PM',
#    'latitude': 40.72217444,
#    'location': '',
#    'longitude': -73.98368779,
#    'postalCode': '',
#    'stAddress1': 'E 2 St & Avenue B',
#    'stAddress2': '',
#    'stationName': 'E 2 St & Avenue B',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 37},
#   {'altitude': '',
#    'availableBikes': 19,
#    'availableDocks': 3,
#    'city': '',
#    'id': 302,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:00 PM',
#    'latitude': 40.72082834,
#    'location': '',
#    'longitude': -73.97793172,
#    'postalCode': '',
#    'stAddress1': 'Avenue D & E 3 St',
#    'stAddress2': '',
#    'stationName': 'Avenue D & E 3 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 25,
#    'city': '',
#    'id': 303,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:02 PM',
#    'latitude': 40.72362738,
#    'location': '',
#    'longitude': -73.99949601,
#    'postalCode': '',
#    'stAddress1': 'Mercer St & Spring St',
#    'stAddress2': '',
#    'stationName': 'Mercer St & Spring St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 25,
#    'city': '',
#    'id': 304,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:04 PM',
#    'latitude': 40.70463334,
#    'location': '',
#    'longitude': -74.01361706,
#    'postalCode': '',
#    'stAddress1': 'Broadway & Battery Pl',
#    'stAddress2': '',
#    'stationName': 'Broadway & Battery Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 34},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 31,
#    'city': '',
#    'id': 305,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:36 PM',
#    'latitude': 40.76095756,
#    'location': '',
#    'longitude': -73.96724467,
#    'postalCode': '',
#    'stAddress1': 'E 58 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 58 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 27,
#    'city': '',
#    'id': 306,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:24 PM',
#    'latitude': 40.70823502,
#    'location': '',
#    'longitude': -74.00530063,
#    'postalCode': '',
#    'stAddress1': 'Cliff St & Fulton St',
#    'stAddress2': '',
#    'stationName': 'Cliff St & Fulton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 37},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 23,
#    'city': '',
#    'id': 307,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:37 PM',
#    'latitude': 40.71427487,
#    'location': '',
#    'longitude': -73.98990025,
#    'postalCode': '',
#    'stAddress1': 'Canal St & Rutgers St',
#    'stAddress2': '',
#    'stationName': 'Canal St & Rutgers St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 17,
#    'city': '',
#    'id': 308,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:53 PM',
#    'latitude': 40.71307916,
#    'location': '',
#    'longitude': -73.99851193,
#    'postalCode': '',
#    'stAddress1': 'St James Pl & Oliver St',
#    'stAddress2': '',
#    'stationName': 'St James Pl & Oliver St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 15,
#    'availableDocks': 24,
#    'city': '',
#    'id': 309,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:02 PM',
#    'latitude': 40.7149787,
#    'location': '',
#    'longitude': -74.013012,
#    'postalCode': '',
#    'stAddress1': 'Murray St & West St',
#    'stAddress2': '',
#    'stationName': 'Murray St & West St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 41},
#   {'altitude': '',
#    'availableBikes': 21,
#    'availableDocks': 15,
#    'city': '',
#    'id': 310,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:05 PM',
#    'latitude': 40.68926942,
#    'location': '',
#    'longitude': -73.98912867,
#    'postalCode': '',
#    'stAddress1': 'State St & Smith St',
#    'stAddress2': '',
#    'stationName': 'State St & Smith St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 36},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 30,
#    'city': '',
#    'id': 311,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#    'latitude': 40.7172274,
#    'location': '',
#    'longitude': -73.98802084,
#    'postalCode': '',
#    'stAddress1': 'Norfolk St & Broome St',
#    'stAddress2': '',
#    'stationName': 'Norfolk St & Broome St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 20,
#    'availableDocks': 11,
#    'city': '',
#    'id': 312,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:14 PM',
#    'latitude': 40.722055,
#    'location': '',
#    'longitude': -73.989111,
#    'postalCode': '',
#    'stAddress1': 'Allen St & Stanton St',
#    'stAddress2': '',
#    'stationName': 'Allen St & Stanton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 18,
#    'availableDocks': 5,
#    'city': '',
#    'id': 313,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:59 PM',
#    'latitude': 40.69610226,
#    'location': '',
#    'longitude': -73.96751037,
#    'postalCode': '',
#    'stAddress1': 'Washington Ave & Park Ave',
#    'stAddress2': '',
#    'stationName': 'Washington Ave & Park Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 23,
#    'availableDocks': 4,
#    'city': '',
#    'id': 315,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:53 PM',
#    'latitude': 40.70355377,
#    'location': '',
#    'longitude': -74.00670227,
#    'postalCode': '',
#    'stAddress1': 'South St & Gouverneur Ln',
#    'stAddress2': '',
#    'stationName': 'South St & Gouverneur Ln',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 43,
#    'city': '',
#    'id': 316,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#    'latitude': 40.70955958,
#    'location': '',
#    'longitude': -74.00653609,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & William St',
#    'stAddress2': '',
#    'stationName': 'Fulton St & William St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 43},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 1,
#    'city': '',
#    'id': 317,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#    'latitude': 40.72453734,
#    'location': '',
#    'longitude': -73.98185424,
#    'postalCode': '',
#    'stAddress1': 'E 6 St & Avenue B',
#    'stAddress2': '',
#    'stationName': 'E 6 St & Avenue B',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 26,
#    'availableDocks': 7,
#    'city': '',
#    'id': 319,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:06 PM',
#    'latitude': 40.711066,
#    'location': '',
#    'longitude': -74.009447,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Broadway',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Broadway',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 28,
#    'availableDocks': 11,
#    'city': '',
#    'id': 320,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#    'latitude': 40.717571,
#    'location': '',
#    'longitude': -74.005549,
#    'postalCode': '',
#    'stAddress1': 'Leonard St & Church St',
#    'stAddress2': '',
#    'stationName': 'Leonard St & Church St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 14,
#    'city': '',
#    'id': 321,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:14 PM',
#    'latitude': 40.69991755,
#    'location': '',
#    'longitude': -73.98971773,
#    'postalCode': '',
#    'stAddress1': 'Cadman Plaza E & Red Cross Pl',
#    'stAddress2': '',
#    'stationName': 'Cadman Plaza E & Red Cross Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 21,
#    'city': '',
#    'id': 322,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:00 PM',
#    'latitude': 40.696192,
#    'location': '',
#    'longitude': -73.991218,
#    'postalCode': '',
#    'stAddress1': 'Clinton St & Tillary St',
#    'stAddress2': '',
#    'stationName': 'Clinton St & Tillary St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 23,
#    'city': '',
#    'id': 323,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:29 PM',
#    'latitude': 40.69236178,
#    'location': '',
#    'longitude': -73.98631746,
#    'postalCode': '',
#    'stAddress1': 'Lawrence St & Willoughby St',
#    'stAddress2': '',
#    'stationName': 'Lawrence St & Willoughby St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 8,
#    'availableDocks': 41,
#    'city': '',
#    'id': 324,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:21 PM',
#    'latitude': 40.689888,
#    'location': '',
# ...
#    'lastCommunicationTime': '2017-01-30 08:11:01 PM',
#    'latitude': 40.6705135,
#    'location': '',
#    'longitude': -73.98876585,
#    'postalCode': '',
#    'stAddress1': '4 Ave & 9 St',
#    'stAddress2': '',
#    'stationName': '4 Ave & 9 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 12,
#    'availableDocks': 15,
#    'city': '',
#    'id': 3404,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#    'latitude': 40.6704922,
#    'location': '',
#    'longitude': -73.98541675,
#    'postalCode': '',
#    'stAddress1': '7 St & 5 Ave',
#    'stAddress2': '',
#    'stationName': '7 St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 11,
#    'city': '',
#    'id': 3405,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:27 PM',
#    'latitude': 40.6704836,
#    'location': '',
#    'longitude': -73.98208968,
#    'postalCode': '',
#    'stAddress1': '5 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': '5 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 15},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 9,
#    'city': '',
#    'id': 3407,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:50 PM',
#    'latitude': 40.67909799721684,
#    'location': '',
#    'longitude': -73.98765474557877,
#    'postalCode': '',
#    'stAddress1': 'Union St & Nevins St',
#    'stAddress2': '',
#    'stationName': 'Union St & Nevins St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 15},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 18,
#    'city': '',
#    'id': 3408,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:23 PM',
#    'latitude': 40.6881529,
#    'location': '',
#    'longitude': -73.99520919,
#    'postalCode': '',
#    'stAddress1': 'Congress St & Clinton St',
#    'stAddress2': '',
#    'stationName': 'Congress St & Clinton St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 29,
#    'city': '',
#    'id': 3409,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:34 PM',
#    'latitude': 40.6867443,
#    'location': '',
#    'longitude': -73.99063168,
#    'postalCode': '',
#    'stAddress1': 'Bergen St & Smith St',
#    'stAddress2': '',
#    'stationName': 'Bergen St & Smith St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 4,
#    'availableDocks': 27,
#    'city': '',
#    'id': 3410,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:18 PM',
#    'latitude': 40.6864442,
#    'location': '',
#    'longitude': -73.98759104,
#    'postalCode': '',
#    'stAddress1': 'Dean St & Hoyt St',
#    'stAddress2': '',
#    'stationName': 'Dean St & Hoyt St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 25,
#    'city': '',
#    'id': 3411,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:10 PM',
#    'latitude': 40.6849668,
#    'location': '',
#    'longitude': -73.98620772,
#    'postalCode': '',
#    'stAddress1': 'Bond St & Bergen St',
#    'stAddress2': '',
#    'stationName': 'Bond St & Bergen St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 10,
#    'city': '',
#    'id': 3412,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:17 PM',
#    'latitude': 40.6853761,
#    'location': '',
#    'longitude': -73.98302136,
#    'postalCode': '',
#    'stAddress1': 'Pacific St & Nevins St',
#    'stAddress2': '',
#    'stationName': 'Pacific St & Nevins St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 15},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 22,
#    'city': '',
#    'id': 3413,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:45 PM',
#    'latitude': 40.6827549,
#    'location': '',
#    'longitude': -73.98258555,
#    'postalCode': '',
#    'stAddress1': 'Wyckoff St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'Wyckoff St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 22},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 31,
#    'city': '',
#    'id': 3414,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:56 PM',
#    'latitude': 40.680944723477296,
#    'location': '',
#    'longitude': -73.97567331790923,
#    'postalCode': '',
#    'stAddress1': 'Bergen St & Flatbush Ave',
#    'stAddress2': '',
#    'stationName': 'Bergen St & Flatbush Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 24,
#    'city': '',
#    'id': 3415,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:55 PM',
#    'latitude': 40.6793307,
#    'location': '',
#    'longitude': -73.97519523,
#    'postalCode': '',
#    'stAddress1': 'Prospect Pl & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'Prospect Pl & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 15,
#    'city': '',
#    'id': 3416,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:50 PM',
#    'latitude': 40.6776147,
#    'location': '',
#    'longitude': -73.97324283,
#    'postalCode': '',
#    'stAddress1': '7 Ave & Park Pl',
#    'stAddress2': '',
#    'stationName': '7 Ave & Park Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 17},
#   {'altitude': '',
#    'availableBikes': 18,
#    'availableDocks': 9,
#    'city': '',
#    'id': 3417,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:34 PM',
#    'latitude': 40.6795766,
#    'location': '',
#    'longitude': -73.97854971,
#    'postalCode': '',
#    'stAddress1': 'Baltic St & 5 Ave',
#    'stAddress2': '',
#    'stationName': 'Baltic St & 5 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 33,
#    'city': '',
#    'id': 3418,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:23 PM',
#    'latitude': 40.6750207,
#    'location': '',
#    'longitude': -73.97111473,
#    'postalCode': '',
#    'stAddress1': 'Plaza St West & Flatbush Ave',
#    'stAddress2': '',
#    'stationName': 'Plaza St West & Flatbush Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 19,
#    'city': '',
#    'id': 3419,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:28 PM',
#    'latitude': 40.6792788,
#    'location': '',
#    'longitude': -73.98154004,
#    'postalCode': '',
#    'stAddress1': 'Douglass St & 4 Ave',
#    'stAddress2': '',
#    'stationName': 'Douglass St & 4 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 7,
#    'city': '',
#    'id': 3420,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:11 PM',
#    'latitude': 40.6802133,
#    'location': '',
#    'longitude': -73.98432695,
#    'postalCode': '',
#    'stAddress1': 'Douglass St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'Douglass St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 21},
#   {'altitude': '',
#    'availableBikes': 10,
#    'availableDocks': 13,
#    'city': '',
#    'id': 3421,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:24 PM',
#    'latitude': 40.6843549,
#    'location': '',
#    'longitude': -73.98901629,
#    'postalCode': '',
#    'stAddress1': 'Hoyt St & Warren St',
#    'stAddress2': '',
#    'stationName': 'Hoyt St & Warren St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 23},
#   {'altitude': '',
#    'availableBikes': 2,
#    'availableDocks': 18,
#    'city': '',
#    'id': 3422,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:58 PM',
#    'latitude': 40.6859296,
#    'location': '',
#    'longitude': -74.00242364,
#    'postalCode': '',
#    'stAddress1': 'Columbia St & Degraw St',
#    'stAddress2': '',
#    'stationName': 'Columbia St & Degraw St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 21},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 16,
#    'city': '',
#    'id': 3423,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:18 PM',
#    'latitude': 40.6610633719006,
#    'location': '',
#    'longitude': -73.97945255041122,
#    'postalCode': '',
#    'stAddress1': 'West Drive & Prospect Park West',
#    'stAddress2': '',
#    'stationName': 'West Drive & Prospect Park West',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 29},
#   {'altitude': '',
#    'availableBikes': 9,
#    'availableDocks': 18,
#    'city': '',
#    'id': 3424,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:58 PM',
#    'latitude': 40.791976,
#    'location': '',
#    'longitude': -73.945993,
#    'postalCode': '',
#    'stAddress1': 'E 106 St & Lexington Ave',
#    'stAddress2': '',
#    'stationName': 'E 106 St & Lexington Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 27},
#   {'altitude': '',
#    'availableBikes': 14,
#    'availableDocks': 19,
#    'city': '',
#    'id': 3425,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:58 PM',
#    'latitude': 40.7892105,
#    'location': '',
#    'longitude': -73.94370784,
#    'postalCode': '',
#    'stAddress1': '2 Ave  & E 104 St',
#    'stAddress2': '',
#    'stationName': '2 Ave  & E 104 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 33},
#   {'altitude': '',
#    'availableBikes': 6,
#    'availableDocks': 31,
#    'city': '',
#    'id': 3427,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:25 PM',
#    'latitude': 40.72430527250332,
#    'location': '',
#    'longitude': -73.99600982666016,
#    'postalCode': '',
#    'stAddress1': 'Lafayette St & Jersey St',
#    'stAddress2': '',
#    'stationName': 'Lafayette St & Jersey St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 40},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 24,
#    'city': '',
#    'id': 3428,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:08 PM',
#    'latitude': 40.740983,
#    'location': '',
#    'longitude': -74.001702,
#    'postalCode': '',
#    'stAddress1': '8 Ave & W 16 St',
#    'stAddress2': '',
#    'stationName': '8 Ave & W 16 St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 25},
#   {'altitude': '',
#    'availableBikes': 3,
#    'availableDocks': 32,
#    'city': '',
#    'id': 3429,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#    'latitude': 40.68506807308177,
#    'location': '',
#    'longitude': -73.97790759801863,
#    'postalCode': '',
#    'stAddress1': 'Hanson Pl & Ashland Pl',
#    'stAddress2': '',
#    'stationName': 'Hanson Pl & Ashland Pl',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 39},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 12,
#    'city': '',
#    'id': 3430,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:48 PM',
#    'latitude': 40.71907891179564,
#    'location': '',
#    'longitude': -73.94223690032959,
#    'postalCode': '',
#    'stAddress1': 'Richardson St & N Henry St',
#    'stAddress2': '',
#    'stationName': 'Richardson St & N Henry St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 19},
#   {'altitude': '',
#    'availableBikes': 13,
#    'availableDocks': 13,
#    'city': '',
#    'id': 3431,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:13 PM',
#    'latitude': 40.746524,
#    'location': '',
#    'longitude': -73.977885,
#    'postalCode': '',
#    'stAddress1': 'E 35 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 35 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 26},
#   {'altitude': '',
#    'availableBikes': 7,
#    'availableDocks': 28,
#    'city': '',
#    'id': 3434,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:12:15 PM',
#    'latitude': 40.79025417330419,
#    'location': '',
#    'longitude': -73.97718340158461,
#    'postalCode': '',
#    'stAddress1': 'W 88 St & West End Ave',
#    'stAddress2': '',
#    'stationName': 'W 88 St & West End Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 35},
#   {'altitude': '',
#    'availableBikes': 11,
#    'availableDocks': 29,
#    'city': '',
#    'id': 3435,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#    'latitude': 40.718822,
#    'location': '',
#    'longitude': -73.99596,
#    'postalCode': '',
#    'stAddress1': 'Grand St & Elizabeth St',
#    'stAddress2': '',
#    'stationName': 'Grand St & Elizabeth St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 45},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 30,
#    'city': '',
#    'id': 3436,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:13:19 PM',
#    'latitude': 40.721319,
#    'location': '',
#    'longitude': -74.010065,
#    'postalCode': '',
#    'stAddress1': 'Greenwich St & Hubert St',
#    'stAddress2': '',
#    'stationName': 'Greenwich St & Hubert St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 0,
#    'city': '',
#    'id': 3437,
#    'landMark': '',
#    'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#    'latitude': 40.79313480986663,
#    'location': '',
#    'longitude': -73.97700369358063,
#    'postalCode': '',
#    'stAddress1': 'Riverside Dr & W 91 St',
#    'stAddress2': '',
#    'stationName': 'Riverside Dr & W 91 St',
#    'statusKey': 3,
#    'statusValue': 'Not In Service',
#    'testStation': False,
#    'totalDocks': 0},
#   {'altitude': '',
#    'availableBikes': 5,
#    'availableDocks': 25,
#    'city': '',
#    'id': 3438,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:09:54 PM',
#    'latitude': 40.772248537721744,
#    'location': '',
#    'longitude': -73.95842134952545,
#    'postalCode': '',
#    'stAddress1': 'E 76 St & 3 Ave',
#    'stAddress2': '',
#    'stationName': 'E 76 St & 3 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 31},
#   {'altitude': '',
#    'availableBikes': 1,
#    'availableDocks': 41,
#    'city': '',
#    'id': 3440,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:11:46 PM',
#    'latitude': 40.692418292578466,
#    'location': '',
#    'longitude': -73.98949474096298,
#    'postalCode': '',
#    'stAddress1': 'Fulton St & Adams St',
#    'stAddress2': '',
#    'stationName': 'Fulton St & Adams St',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 43},
#   {'altitude': '',
#    'availableBikes': 0,
#    'availableDocks': 41,
#    'city': '',
#    'id': 3443,
#    'landMark': '',
#    'lastCommunicationTime': '2017-01-30 08:10:04 PM',
#    'latitude': 40.76132983124814,
#    'location': '',
#    'longitude': -73.97982001304626,
#    'postalCode': '',
#    'stAddress1': 'W 52 St & 6 Ave',
#    'stAddress2': '',
#    'stationName': 'W 52 St & 6 Ave',
#    'statusKey': 1,
#    'statusValue': 'In Service',
#    'testStation': False,
#    'totalDocks': 41}]}

# %%
# will access json files similar to dictionary
r.json().keys()
# the keys are executionTime and stationBeanList
# Out:
# dict_keys(['stationBeanList', 'executionTime'])

# %%
r.json()['executionTime'] # time file was created
r.json()['stationBeanList'] # list of stations
# Out:
# [{'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 34,
#   'city': '',
#   'id': 72,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:32 PM',
#   'latitude': 40.76727216,
#   'location': '',
#   'longitude': -73.99392888,
#   'postalCode': '',
#   'stAddress1': 'W 52 St & 11 Ave',
#   'stAddress2': '',
#   'stationName': 'W 52 St & 11 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 24,
#   'availableDocks': 9,
#   'city': '',
#   'id': 79,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:25 PM',
#   'latitude': 40.71911552,
#   'location': '',
#   'longitude': -74.00666661,
#   'postalCode': '',
#   'stAddress1': 'Franklin St & W Broadway',
#   'stAddress2': '',
#   'stationName': 'Franklin St & W Broadway',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 2,
#   'availableDocks': 25,
#   'city': '',
#   'id': 82,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:07 PM',
#   'latitude': 40.71117416,
#   'location': '',
#   'longitude': -74.00016545,
#   'postalCode': '',
#   'stAddress1': 'St James Pl & Pearl St',
#   'stAddress2': '',
#   'stationName': 'St James Pl & Pearl St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 51,
#   'city': '',
#   'id': 83,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:06 PM',
#   'latitude': 40.68382604,
#   'location': '',
#   'longitude': -73.97632328,
#   'postalCode': '',
#   'stAddress1': 'Atlantic Ave & Fort Greene Pl',
#   'stAddress2': '',
#   'stationName': 'Atlantic Ave & Fort Greene Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 62},
#  {'altitude': '',
#   'availableBikes': 7,
#   'availableDocks': 31,
#   'city': '',
#   'id': 116,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:01 PM',
#   'latitude': 40.74177603,
#   'location': '',
#   'longitude': -74.00149746,
#   'postalCode': '',
#   'stAddress1': 'W 17 St & 8 Ave',
#   'stAddress2': '',
#   'stationName': 'W 17 St & 8 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 12,
#   'availableDocks': 7,
#   'city': '',
#   'id': 119,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:57 PM',
#   'latitude': 40.69608941,
#   'location': '',
#   'longitude': -73.97803415,
#   'postalCode': '',
#   'stAddress1': 'Park Ave & St Edwards St',
#   'stAddress2': '',
#   'stationName': 'Park Ave & St Edwards St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 13,
#   'city': '',
#   'id': 120,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#   'latitude': 40.68676793,
#   'location': '',
#   'longitude': -73.95928168,
#   'postalCode': '',
#   'stAddress1': 'Lexington Ave & Classon Ave',
#   'stAddress2': '',
#   'stationName': 'Lexington Ave & Classon Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 20,
#   'availableDocks': 9,
#   'city': '',
#   'id': 127,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:52 PM',
#   'latitude': 40.73172428,
#   'location': '',
#   'longitude': -74.00674436,
#   'postalCode': '',
#   'stAddress1': 'Barrow St & Hudson St',
#   'stAddress2': '',
#   'stationName': 'Barrow St & Hudson St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 16,
#   'city': '',
#   'id': 128,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:17 PM',
#   'latitude': 40.72710258,
#   'location': '',
#   'longitude': -74.00297088,
#   'postalCode': '',
#   'stAddress1': 'MacDougal St & Prince St',
#   'stAddress2': '',
#   'stationName': 'MacDougal St & Prince St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 30},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 0,
#   'city': '',
#   'id': 137,
#   'landMark': '',
#   'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#   'latitude': 40.761628,
#   'location': '',
#   'longitude': -73.972924,
#   'postalCode': '',
#   'stAddress1': 'E 56 St & Madison Ave',
#   'stAddress2': '',
#   'stationName': 'E 56 St & Madison Ave',
#   'statusKey': 3,
#   'statusValue': 'Not In Service',
#   'testStation': False,
#   'totalDocks': 0},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 21,
#   'city': '',
#   'id': 143,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:45 PM',
#   'latitude': 40.69239502,
#   'location': '',
#   'longitude': -73.99337909,
#   'postalCode': '',
#   'stAddress1': 'Clinton St & Joralemon St',
#   'stAddress2': '',
#   'stationName': 'Clinton St & Joralemon St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 24},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 9,
#   'city': '',
#   'id': 144,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:53 PM',
#   'latitude': 40.69839895,
#   'location': '',
#   'longitude': -73.98068914,
#   'postalCode': '',
#   'stAddress1': 'Nassau St & Navy St',
#   'stAddress2': '',
#   'stationName': 'Nassau St & Navy St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 33,
#   'availableDocks': 6,
#   'city': '',
#   'id': 146,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:15 PM',
#   'latitude': 40.71625008,
#   'location': '',
#   'longitude': -74.0091059,
#   'postalCode': '',
#   'stAddress1': 'Hudson St & Reade St',
#   'stAddress2': '',
#   'stationName': 'Hudson St & Reade St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 31,
#   'availableDocks': 2,
#   'city': '',
#   'id': 147,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:33 PM',
#   'latitude': 40.71542197,
#   'location': '',
#   'longitude': -74.01121978,
#   'postalCode': '',
#   'stAddress1': 'Greenwich St & Warren St',
#   'stAddress2': '',
#   'stationName': 'Greenwich St & Warren St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 18,
#   'city': '',
#   'id': 150,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:13 PM',
#   'latitude': 40.7208736,
#   'location': '',
#   'longitude': -73.98085795,
#   'postalCode': '',
#   'stAddress1': 'E 2 St & Avenue C',
#   'stAddress2': '',
#   'stationName': 'E 2 St & Avenue C',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 30,
#   'city': '',
#   'id': 151,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#   'latitude': 40.722103786686034,
#   'location': '',
#   'longitude': -73.99724900722504,
#   'postalCode': '',
#   'stAddress1': 'Cleveland Pl & Spring St',
#   'stAddress2': '',
#   'stationName': 'Cleveland Pl & Spring St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 25,
#   'availableDocks': 4,
#   'city': '',
#   'id': 152,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:47 PM',
#   'latitude': 40.71473993,
#   'location': '',
#   'longitude': -74.00910627,
#   'postalCode': '',
#   'stAddress1': 'Warren St & Church St',
#   'stAddress2': '',
#   'stationName': 'Warren St & Church St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 29},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 54,
#   'city': '',
#   'id': 153,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:50 PM',
#   'latitude': 40.752062307,
#   'location': '',
#   'longitude': -73.9816324043,
#   'postalCode': '',
#   'stAddress1': 'E 40 St & 5 Ave',
#   'stAddress2': '',
#   'stationName': 'E 40 St & 5 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 55},
#  {'altitude': '',
#   'availableBikes': 7,
#   'availableDocks': 16,
#   'city': '',
#   'id': 157,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:26 PM',
#   'latitude': 40.69089272,
#   'location': '',
#   'longitude': -73.99612349,
#   'postalCode': '',
#   'stAddress1': 'Henry St & Atlantic Ave',
#   'stAddress2': '',
#   'stationName': 'Henry St & Atlantic Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 32,
#   'availableDocks': 3,
#   'city': '',
#   'id': 161,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:39 PM',
#   'latitude': 40.72917025,
#   'location': '',
#   'longitude': -73.99810231,
#   'postalCode': '',
#   'stAddress1': 'LaGuardia Pl & W 3 St',
#   'stAddress2': '',
#   'stationName': 'LaGuardia Pl & W 3 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 8,
#   'availableDocks': 38,
#   'city': '',
#   'id': 164,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:33 PM',
#   'latitude': 40.75323098,
#   'location': '',
#   'longitude': -73.97032517,
#   'postalCode': '',
#   'stAddress1': 'E 47 St & 2 Ave',
#   'stAddress2': '',
#   'stationName': 'E 47 St & 2 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 47},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 44,
#   'city': '',
#   'id': 167,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:51 PM',
#   'latitude': 40.7489006,
#   'location': '',
#   'longitude': -73.97604882,
#   'postalCode': '',
#   'stAddress1': 'E 39 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 39 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 45},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 42,
#   'city': '',
#   'id': 168,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:04 PM',
#   'latitude': 40.73971301,
#   'location': '',
#   'longitude': -73.99456405,
#   'postalCode': '',
#   'stAddress1': 'W 18 St & 6 Ave',
#   'stAddress2': '',
#   'stationName': 'W 18 St & 6 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 47},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 49,
#   'city': '',
#   'id': 173,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:52 PM',
#   'latitude': 40.76068327096592,
#   'location': '',
#   'longitude': -73.9845272898674,
#   'postalCode': '',
#   'stAddress1': 'Broadway & W 49 St',
#   'stAddress2': '',
#   'stationName': 'Broadway & W 49 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 51},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 20,
#   'city': '',
#   'id': 174,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:08 PM',
#   'latitude': 40.7381765,
#   'location': '',
#   'longitude': -73.97738662,
#   'postalCode': '',
#   'stAddress1': 'E 25 St & 1 Ave',
#   'stAddress2': '',
#   'stationName': 'E 25 St & 1 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 30},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 43,
#   'city': '',
#   'id': 195,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:26 PM',
#   'latitude': 40.70905623,
#   'location': '',
#   'longitude': -74.01043382,
#   'postalCode': '',
#   'stAddress1': 'Liberty St & Broadway',
#   'stAddress2': '',
#   'stationName': 'Liberty St & Broadway',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 45},
#  {'altitude': '',
#   'availableBikes': 2,
#   'availableDocks': 25,
#   'city': '',
#   'id': 212,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:09 PM',
#   'latitude': 40.74334935,
#   'location': '',
#   'longitude': -74.00681753,
#   'postalCode': '',
#   'stAddress1': 'W 16 St & The High Line',
#   'stAddress2': '',
#   'stationName': 'W 16 St & The High Line',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 28},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 21,
#   'city': '',
#   'id': 216,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:03 PM',
#   'latitude': 40.70037867,
#   'location': '',
#   'longitude': -73.99548059,
#   'postalCode': '',
#   'stAddress1': 'Columbia Heights & Cranberry St',
#   'stAddress2': '',
#   'stationName': 'Columbia Heights & Cranberry St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 21,
#   'availableDocks': 17,
#   'city': '',
#   'id': 217,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:45 PM',
#   'latitude': 40.70277159,
#   'location': '',
#   'longitude': -73.99383605,
#   'postalCode': '',
#   'stAddress1': 'Old Fulton St',
#   'stAddress2': '',
#   'stationName': 'Old Fulton St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 3,
#   'city': '',
#   'id': 223,
#   'landMark': '',
#   'lastCommunicationTime': '2016-11-22 07:39:47 AM',
#   'latitude': 40.73781509,
#   'location': '',
#   'longitude': -73.99994661,
#   'postalCode': '',
#   'stAddress1': 'W 13 St & 7 Ave',
#   'stAddress2': '',
#   'stationName': 'W 13 St & 7 Ave',
#   'statusKey': 3,
#   'statusValue': 'Not In Service',
#   'testStation': False,
#   'totalDocks': 3},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 29,
#   'city': '',
#   'id': 224,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:20 PM',
#   'latitude': 40.71146364,
#   'location': '',
#   'longitude': -74.00552427,
#   'postalCode': '',
#   'stAddress1': 'Spruce St & Nassau St',
#   'stAddress2': '',
#   'stationName': 'Spruce St & Nassau St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 20,
#   'availableDocks': 15,
#   'city': '',
#   'id': 225,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:12 PM',
#   'latitude': 40.74195138,
#   'location': '',
#   'longitude': -74.00803013,
#   'postalCode': '',
#   'stAddress1': 'W 14 St & The High Line',
#   'stAddress2': '',
#   'stationName': 'W 14 St & The High Line',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 37},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 54,
#   'city': '',
#   'id': 228,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:35 PM',
#   'latitude': 40.7546011026,
#   'location': '',
#   'longitude': -73.971878855,
#   'postalCode': '',
#   'stAddress1': 'E 48 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 48 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 55},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 7,
#   'city': '',
#   'id': 229,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:54 PM',
#   'latitude': 40.72743423,
#   'location': '',
#   'longitude': -73.99379025,
#   'postalCode': '',
#   'stAddress1': 'Great Jones St',
#   'stAddress2': '',
#   'stationName': 'Great Jones St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 13,
#   'city': '',
#   'id': 232,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:05 PM',
#   'latitude': 40.69597683,
#   'location': '',
#   'longitude': -73.99014892,
#   'postalCode': '',
#   'stAddress1': 'Cadman Plaza E & Tillary St',
#   'stAddress2': '',
#   'stationName': 'Cadman Plaza E & Tillary St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 27,
#   'availableDocks': 12,
#   'city': '',
#   'id': 236,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:24 PM',
#   'latitude': 40.7284186,
#   'location': '',
#   'longitude': -73.98713956,
#   'postalCode': '',
#   'stAddress1': 'St Marks Pl & 2 Ave',
#   'stAddress2': '',
#   'stationName': 'St Marks Pl & 2 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 26,
#   'availableDocks': 12,
#   'city': '',
#   'id': 237,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:44 PM',
#   'latitude': 40.73047309,
#   'location': '',
#   'longitude': -73.98672378,
#   'postalCode': '',
#   'stAddress1': 'E 11 St & 2 Ave',
#   'stAddress2': '',
#   'stationName': 'E 11 St & 2 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 17,
#   'availableDocks': 14,
#   'city': '',
#   'id': 238,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:16 PM',
#   'latitude': 40.7361967,
#   'location': '',
#   'longitude': -74.00859207,
#   'postalCode': '',
#   'stAddress1': 'Bank St & Washington St',
#   'stAddress2': '',
#   'stationName': 'Bank St & Washington St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 31,
#   'city': '',
#   'id': 239,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#   'latitude': 40.69196566,
#   'location': '',
#   'longitude': -73.9813018,
#   'postalCode': '',
#   'stAddress1': 'Willoughby St & Fleet St',
#   'stAddress2': '',
#   'stationName': 'Willoughby St & Fleet St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 16,
#   'city': '',
#   'id': 241,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:46 PM',
#   'latitude': 40.68981035,
#   'location': '',
#   'longitude': -73.97493121,
#   'postalCode': '',
#   'stAddress1': 'DeKalb Ave & S Portland Ave',
#   'stAddress2': '',
#   'stationName': 'DeKalb Ave & S Portland Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 16,
#   'availableDocks': 7,
#   'city': '',
#   'id': 242,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:21 PM',
#   'latitude': 40.697787,
#   'location': '',
#   'longitude': -73.973736,
#   'postalCode': '',
#   'stAddress1': 'Carlton Ave & Flushing Ave',
#   'stAddress2': '',
#   'stationName': 'Carlton Ave & Flushing Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 19,
#   'availableDocks': 12,
#   'city': '',
#   'id': 243,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:44 PM',
#   'latitude': 40.688226,
#   'location': '',
#   'longitude': -73.979382,
#   'postalCode': '',
#   'stAddress1': 'Fulton St & Rockwell Pl',
#   'stAddress2': '',
#   'stationName': 'Fulton St & Rockwell Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 21,
#   'city': '',
#   'id': 244,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:37 PM',
#   'latitude': 40.69196035,
#   'location': '',
#   'longitude': -73.96536851,
#   'postalCode': '',
#   'stAddress1': 'Willoughby Ave & Hall St',
#   'stAddress2': '',
#   'stationName': 'Willoughby Ave & Hall St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 23,
#   'city': '',
#   'id': 245,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:31 PM',
#   'latitude': 40.69327018,
#   'location': '',
#   'longitude': -73.97703874,
#   'postalCode': '',
#   'stAddress1': 'Myrtle Ave & St Edwards St',
#   'stAddress2': '',
#   'stationName': 'Myrtle Ave & St Edwards St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 14,
#   'availableDocks': 6,
#   'city': '',
#   'id': 247,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:02 PM',
#   'latitude': 40.73535398,
#   'location': '',
#   'longitude': -74.00483091,
#   'postalCode': '',
#   'stAddress1': 'Perry St & Bleecker St',
#   'stAddress2': '',
#   'stationName': 'Perry St & Bleecker St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 20},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 17,
#   'city': '',
#   'id': 248,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:22 PM',
#   'latitude': 40.72185379,
#   'location': '',
#   'longitude': -74.00771779,
#   'postalCode': '',
#   'stAddress1': 'Laight St & Hudson St',
#   'stAddress2': '',
#   'stationName': 'Laight St & Hudson St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 12,
#   'availableDocks': 15,
#   'city': '',
#   'id': 249,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:22 PM',
#   'latitude': 40.71870987,
#   'location': '',
#   'longitude': -74.0090009,
#   'postalCode': '',
#   'stAddress1': 'Harrison St & Hudson St',
#   'stAddress2': '',
#   'stationName': 'Harrison St & Hudson St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 19,
#   'availableDocks': 7,
#   'city': '',
#   'id': 251,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:07 PM',
#   'latitude': 40.72317958,
#   'location': '',
#   'longitude': -73.99480012,
#   'postalCode': '',
#   'stAddress1': 'Mott St & Prince St',
#   'stAddress2': '',
#   'stationName': 'Mott St & Prince St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 33,
#   'availableDocks': 0,
#   'city': '',
#   'id': 252,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:30 PM',
#   'latitude': 40.73226398,
#   'location': '',
#   'longitude': -73.99852205,
#   'postalCode': '',
#   'stAddress1': 'MacDougal St & Washington Sq',
#   'stAddress2': '',
#   'stationName': 'MacDougal St & Washington Sq',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 43,
#   'availableDocks': 10,
#   'city': '',
#   'id': 253,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:19 PM',
#   'latitude': 40.73543934,
#   'location': '',
#   'longitude': -73.99453948,
#   'postalCode': '',
#   'stAddress1': 'W 13 St & 5 Ave',
#   'stAddress2': '',
#   'stationName': 'W 13 St & 5 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 55},
#  {'altitude': '',
#   'availableBikes': 20,
#   'availableDocks': 9,
#   'city': '',
#   'id': 254,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:00 PM',
#   'latitude': 40.73532427,
#   'location': '',
#   'longitude': -73.99800419,
#   'postalCode': '',
#   'stAddress1': 'W 11 St & 6 Ave',
#   'stAddress2': '',
#   'stationName': 'W 11 St & 6 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 21,
#   'availableDocks': 17,
#   'city': '',
#   'id': 257,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:57 PM',
#   'latitude': 40.71939226,
#   'location': '',
#   'longitude': -74.00247214,
#   'postalCode': '',
#   'stAddress1': 'Lispenard St & Broadway',
#   'stAddress2': '',
#   'stationName': 'Lispenard St & Broadway',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 12,
#   'city': '',
#   'id': 258,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#   'latitude': 40.68940747,
#   'location': '',
#   'longitude': -73.96885458,
#   'postalCode': '',
#   'stAddress1': 'DeKalb Ave & Vanderbilt Ave',
#   'stAddress2': '',
#   'stationName': 'DeKalb Ave & Vanderbilt Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 26,
#   'availableDocks': 11,
#   'city': '',
#   'id': 259,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:18 PM',
#   'latitude': 40.70122128,
#   'location': '',
#   'longitude': -74.01234218,
#   'postalCode': '',
#   'stAddress1': 'South St & Whitehall St',
#   'stAddress2': '',
#   'stationName': 'South St & Whitehall St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 18,
#   'availableDocks': 16,
#   'city': '',
#   'id': 260,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:07 PM',
#   'latitude': 40.70365182,
#   'location': '',
#   'longitude': -74.01167797,
#   'postalCode': '',
#   'stAddress1': 'Broad St & Bridge St',
#   'stAddress2': '',
#   'stationName': 'Broad St & Bridge St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 14,
#   'city': '',
#   'id': 261,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:31 PM',
#   'latitude': 40.69474881,
#   'location': '',
#   'longitude': -73.98362464,
#   'postalCode': '',
#   'stAddress1': 'Johnson St & Gold St',
#   'stAddress2': '',
#   'stationName': 'Johnson St & Gold St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 17,
#   'city': '',
#   'id': 262,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:15 PM',
#   'latitude': 40.6917823,
#   'location': '',
#   'longitude': -73.9737299,
#   'postalCode': '',
#   'stAddress1': 'Washington Park',
#   'stAddress2': '',
#   'stationName': 'Washington Park',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 24},
#  {'altitude': '',
#   'availableBikes': 17,
#   'availableDocks': 9,
#   'city': '',
#   'id': 264,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:49 PM',
#   'latitude': 40.70706456,
#   'location': '',
#   'longitude': -74.00731853,
#   'postalCode': '',
#   'stAddress1': 'Maiden Ln & Pearl St',
#   'stAddress2': '',
#   'stationName': 'Maiden Ln & Pearl St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 30,
#   'city': '',
#   'id': 265,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:49 PM',
#   'latitude': 40.72229346,
#   'location': '',
#   'longitude': -73.99147535,
#   'postalCode': '',
#   'stAddress1': 'Stanton St & Chrystie St',
#   'stAddress2': '',
#   'stationName': 'Stanton St & Chrystie St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 13,
#   'city': '',
#   'id': 266,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:40 PM',
#   'latitude': 40.72368361,
#   'location': '',
#   'longitude': -73.97574813,
#   'postalCode': '',
#   'stAddress1': 'Avenue D & E 8 St',
#   'stAddress2': '',
#   'stationName': 'Avenue D & E 8 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 24},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 55,
#   'city': '',
#   'id': 267,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:30 PM',
#   'latitude': 40.75097711,
#   'location': '',
#   'longitude': -73.98765428,
#   'postalCode': '',
#   'stAddress1': 'Broadway & W 36 St',
#   'stAddress2': '',
#   'stationName': 'Broadway & W 36 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 57},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 12,
#   'city': '',
#   'id': 268,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:17 PM',
#   'latitude': 40.71910537,
#   'location': '',
#   'longitude': -73.99973337,
#   'postalCode': '',
#   'stAddress1': 'Howard St & Centre St',
#   'stAddress2': '',
#   'stationName': 'Howard St & Centre St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 14,
#   'availableDocks': 9,
#   'city': '',
#   'id': 270,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:01 PM',
#   'latitude': 40.69308257,
#   'location': '',
#   'longitude': -73.97178913,
#   'postalCode': '',
#   'stAddress1': 'Adelphi St & Myrtle Ave',
#   'stAddress2': '',
#   'stationName': 'Adelphi St & Myrtle Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 21,
#   'city': '',
#   'id': 274,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:27 PM',
#   'latitude': 40.68691865,
#   'location': '',
#   'longitude': -73.976682,
#   'postalCode': '',
#   'stAddress1': 'Lafayette Ave & Fort Greene Pl',
#   'stAddress2': '',
#   'stationName': 'Lafayette Ave & Fort Greene Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 14,
#   'city': '',
#   'id': 275,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:04 PM',
#   'latitude': 40.68650065,
#   'location': '',
#   'longitude': -73.96563307,
#   'postalCode': '',
#   'stAddress1': 'Washington Ave & Greene Ave',
#   'stAddress2': '',
#   'stationName': 'Washington Ave & Greene Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 18,
#   'availableDocks': 5,
#   'city': '',
#   'id': 276,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#   'latitude': 40.71748752,
#   'location': '',
#   'longitude': -74.0104554,
#   'postalCode': '',
#   'stAddress1': 'Duane St & Greenwich St',
#   'stAddress2': '',
#   'stationName': 'Duane St & Greenwich St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 25},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 13,
#   'city': '',
#   'id': 278,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:39 PM',
#   'latitude': 40.69766564,
#   'location': '',
#   'longitude': -73.98476437,
#   'postalCode': '',
#   'stAddress1': 'Concord St & Bridge St',
#   'stAddress2': '',
#   'stationName': 'Concord St & Bridge St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 3,
#   'availableDocks': 33,
#   'city': '',
#   'id': 279,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:09 PM',
#   'latitude': 40.707873,
#   'location': '',
#   'longitude': -74.00167,
#   'postalCode': '',
#   'stAddress1': 'Peck Slip & Front St',
#   'stAddress2': '',
#   'stationName': 'Peck Slip & Front St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 36},
#  {'altitude': '',
#   'availableBikes': 25,
#   'availableDocks': 6,
#   'city': '',
#   'id': 280,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:56 PM',
#   'latitude': 40.73331967,
#   'location': '',
#   'longitude': -73.99510132,
#   'postalCode': '',
#   'stAddress1': 'E 10 St & 5 Ave',
#   'stAddress2': '',
#   'stationName': 'E 10 St & 5 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 57,
#   'city': '',
#   'id': 281,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:35 PM',
#   'latitude': 40.7643971,
#   'location': '',
#   'longitude': -73.97371465,
#   'postalCode': '',
#   'stAddress1': 'Grand Army Plaza & Central Park S',
#   'stAddress2': '',
#   'stationName': 'Grand Army Plaza & Central Park S',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 59},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 22,
#   'city': '',
#   'id': 282,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:52 PM',
#   'latitude': 40.707644944175705,
#   'location': '',
#   'longitude': -73.96841526031494,
#   'postalCode': '',
#   'stAddress1': 'Kent Ave & S 11 St',
#   'stAddress2': '',
#   'stationName': 'Kent Ave & S 11 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 34,
#   'availableDocks': 3,
#   'city': '',
#   'id': 284,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:01 PM',
#   'latitude': 40.7390169121,
#   'location': '',
#   'longitude': -74.0026376103,
#   'postalCode': '',
#   'stAddress1': 'Greenwich Ave & 8 Ave',
#   'stAddress2': '',
#   'stationName': 'Greenwich Ave & 8 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 43},
#  {'altitude': '',
#   'availableBikes': 29,
#   'availableDocks': 18,
#   'city': '',
#   'id': 285,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:13 PM',
#   'latitude': 40.73454567,
#   'location': '',
#   'longitude': -73.99074142,
#   'postalCode': '',
#   'stAddress1': 'Broadway & E 14 St',
#   'stAddress2': '',
#   'stationName': 'Broadway & E 14 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 47},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 13,
#   'city': '',
#   'id': 289,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:53 PM',
#   'latitude': 40.6845683,
#   'location': '',
#   'longitude': -73.95881081,
#   'postalCode': '',
#   'stAddress1': 'Monroe St & Classon Ave',
#   'stAddress2': '',
#   'stationName': 'Monroe St & Classon Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 7,
#   'city': '',
#   'id': 291,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:54 PM',
#   'latitude': 40.713126,
#   'location': '',
#   'longitude': -73.984844,
#   'postalCode': '',
#   'stAddress1': 'Madison St & Montgomery St',
#   'stAddress2': '',
#   'stationName': 'Madison St & Montgomery St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 20},
#  {'altitude': '',
#   'availableBikes': 2,
#   'availableDocks': 53,
#   'city': '',
#   'id': 293,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:05 PM',
#   'latitude': 40.73028666,
#   'location': '',
#   'longitude': -73.9907647,
#   'postalCode': '',
#   'stAddress1': 'Lafayette St & E 8 St',
#   'stAddress2': '',
#   'stationName': 'Lafayette St & E 8 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 55},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 24,
#   'city': '',
#   'id': 295,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:14 PM',
#   'latitude': 40.71406667,
#   'location': '',
#   'longitude': -73.99293911,
#   'postalCode': '',
#   'stAddress1': 'Pike St & E Broadway',
#   'stAddress2': '',
#   'stationName': 'Pike St & E Broadway',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 24},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 23,
#   'city': '',
#   'id': 296,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:14 PM',
#   'latitude': 40.71413089,
#   'location': '',
#   'longitude': -73.9970468,
#   'postalCode': '',
#   'stAddress1': 'Division St & Bowery',
#   'stAddress2': '',
#   'stationName': 'Division St & Bowery',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 15,
#   'city': '',
#   'id': 297,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:33 PM',
#   'latitude': 40.734232,
#   'location': '',
#   'longitude': -73.986923,
#   'postalCode': '',
#   'stAddress1': 'E 15 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 15 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 0,
#   'city': '',
#   'id': 298,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-13 09:25:10 AM',
#   'latitude': 40.68683208,
#   'location': '',
#   'longitude': -73.9796772,
#   'postalCode': '',
#   'stAddress1': '3 Ave & Schermerhorn St',
#   'stAddress2': '',
#   'stationName': '3 Ave & Schermerhorn St',
#   'statusKey': 3,
#   'statusValue': 'Not In Service',
#   'testStation': False,
#   'totalDocks': 8},
#  {'altitude': '',
#   'availableBikes': 30,
#   'availableDocks': 4,
#   'city': '',
#   'id': 301,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:03 PM',
#   'latitude': 40.72217444,
#   'location': '',
#   'longitude': -73.98368779,
#   'postalCode': '',
#   'stAddress1': 'E 2 St & Avenue B',
#   'stAddress2': '',
#   'stationName': 'E 2 St & Avenue B',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 37},
#  {'altitude': '',
#   'availableBikes': 19,
#   'availableDocks': 3,
#   'city': '',
#   'id': 302,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:00 PM',
#   'latitude': 40.72082834,
#   'location': '',
#   'longitude': -73.97793172,
#   'postalCode': '',
#   'stAddress1': 'Avenue D & E 3 St',
#   'stAddress2': '',
#   'stationName': 'Avenue D & E 3 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 25,
#   'city': '',
#   'id': 303,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:02 PM',
#   'latitude': 40.72362738,
#   'location': '',
#   'longitude': -73.99949601,
#   'postalCode': '',
#   'stAddress1': 'Mercer St & Spring St',
#   'stAddress2': '',
#   'stationName': 'Mercer St & Spring St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 25,
#   'city': '',
#   'id': 304,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:04 PM',
#   'latitude': 40.70463334,
#   'location': '',
#   'longitude': -74.01361706,
#   'postalCode': '',
#   'stAddress1': 'Broadway & Battery Pl',
#   'stAddress2': '',
#   'stationName': 'Broadway & Battery Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 34},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 31,
#   'city': '',
#   'id': 305,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:36 PM',
#   'latitude': 40.76095756,
#   'location': '',
#   'longitude': -73.96724467,
#   'postalCode': '',
#   'stAddress1': 'E 58 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 58 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 27,
#   'city': '',
#   'id': 306,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:24 PM',
#   'latitude': 40.70823502,
#   'location': '',
#   'longitude': -74.00530063,
#   'postalCode': '',
#   'stAddress1': 'Cliff St & Fulton St',
#   'stAddress2': '',
#   'stationName': 'Cliff St & Fulton St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 37},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 23,
#   'city': '',
#   'id': 307,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:37 PM',
#   'latitude': 40.71427487,
#   'location': '',
#   'longitude': -73.98990025,
#   'postalCode': '',
#   'stAddress1': 'Canal St & Rutgers St',
#   'stAddress2': '',
#   'stationName': 'Canal St & Rutgers St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 29},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 17,
#   'city': '',
#   'id': 308,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:53 PM',
#   'latitude': 40.71307916,
#   'location': '',
#   'longitude': -73.99851193,
#   'postalCode': '',
#   'stAddress1': 'St James Pl & Oliver St',
#   'stAddress2': '',
#   'stationName': 'St James Pl & Oliver St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 15,
#   'availableDocks': 24,
#   'city': '',
#   'id': 309,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:02 PM',
#   'latitude': 40.7149787,
#   'location': '',
#   'longitude': -74.013012,
#   'postalCode': '',
#   'stAddress1': 'Murray St & West St',
#   'stAddress2': '',
#   'stationName': 'Murray St & West St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 41},
#  {'altitude': '',
#   'availableBikes': 21,
#   'availableDocks': 15,
#   'city': '',
#   'id': 310,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:05 PM',
#   'latitude': 40.68926942,
#   'location': '',
#   'longitude': -73.98912867,
#   'postalCode': '',
#   'stAddress1': 'State St & Smith St',
#   'stAddress2': '',
#   'stationName': 'State St & Smith St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 36},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 30,
#   'city': '',
#   'id': 311,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#   'latitude': 40.7172274,
#   'location': '',
#   'longitude': -73.98802084,
#   'postalCode': '',
#   'stAddress1': 'Norfolk St & Broome St',
#   'stAddress2': '',
#   'stationName': 'Norfolk St & Broome St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 20,
#   'availableDocks': 11,
#   'city': '',
#   'id': 312,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:14 PM',
#   'latitude': 40.722055,
#   'location': '',
#   'longitude': -73.989111,
#   'postalCode': '',
#   'stAddress1': 'Allen St & Stanton St',
#   'stAddress2': '',
#   'stationName': 'Allen St & Stanton St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 18,
#   'availableDocks': 5,
#   'city': '',
#   'id': 313,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:59 PM',
#   'latitude': 40.69610226,
#   'location': '',
#   'longitude': -73.96751037,
#   'postalCode': '',
#   'stAddress1': 'Washington Ave & Park Ave',
#   'stAddress2': '',
#   'stationName': 'Washington Ave & Park Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 23,
#   'availableDocks': 4,
#   'city': '',
#   'id': 315,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:53 PM',
#   'latitude': 40.70355377,
#   'location': '',
#   'longitude': -74.00670227,
#   'postalCode': '',
#   'stAddress1': 'South St & Gouverneur Ln',
#   'stAddress2': '',
#   'stationName': 'South St & Gouverneur Ln',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 29},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 43,
#   'city': '',
#   'id': 316,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#   'latitude': 40.70955958,
#   'location': '',
#   'longitude': -74.00653609,
#   'postalCode': '',
#   'stAddress1': 'Fulton St & William St',
#   'stAddress2': '',
#   'stationName': 'Fulton St & William St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 43},
#  {'altitude': '',
#   'availableBikes': 26,
#   'availableDocks': 1,
#   'city': '',
#   'id': 317,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:59 PM',
#   'latitude': 40.72453734,
#   'location': '',
#   'longitude': -73.98185424,
#   'postalCode': '',
#   'stAddress1': 'E 6 St & Avenue B',
#   'stAddress2': '',
#   'stationName': 'E 6 St & Avenue B',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 26,
#   'availableDocks': 7,
#   'city': '',
#   'id': 319,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:06 PM',
#   'latitude': 40.711066,
#   'location': '',
#   'longitude': -74.009447,
#   'postalCode': '',
#   'stAddress1': 'Fulton St & Broadway',
#   'stAddress2': '',
#   'stationName': 'Fulton St & Broadway',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 28,
#   'availableDocks': 11,
#   'city': '',
#   'id': 320,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:52 PM',
#   'latitude': 40.717571,
#   'location': '',
#   'longitude': -74.005549,
#   'postalCode': '',
#   'stAddress1': 'Leonard St & Church St',
#   'stAddress2': '',
#   'stationName': 'Leonard St & Church St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 14,
#   'city': '',
#   'id': 321,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:14 PM',
#   'latitude': 40.69991755,
#   'location': '',
#   'longitude': -73.98971773,
#   'postalCode': '',
#   'stAddress1': 'Cadman Plaza E & Red Cross Pl',
#   'stAddress2': '',
#   'stationName': 'Cadman Plaza E & Red Cross Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 21,
#   'city': '',
#   'id': 322,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:00 PM',
#   'latitude': 40.696192,
#   'location': '',
#   'longitude': -73.991218,
#   'postalCode': '',
#   'stAddress1': 'Clinton St & Tillary St',
#   'stAddress2': '',
#   'stationName': 'Clinton St & Tillary St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 12,
#   'availableDocks': 23,
#   'city': '',
#   'id': 323,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:29 PM',
#   'latitude': 40.69236178,
#   'location': '',
#   'longitude': -73.98631746,
#   'postalCode': '',
#   'stAddress1': 'Lawrence St & Willoughby St',
#   'stAddress2': '',
#   'stationName': 'Lawrence St & Willoughby St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 8,
#   'availableDocks': 41,
#   'city': '',
#   'id': 324,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:21 PM',
#   'latitude': 40.689888,
#   'location': '',
#   'longitude': -73.981013,
#   'postalCode': '',
#   'stAddress1': 'DeKalb Ave & Hudson Ave',
#   'stAddress2': '',
#   'stationName': 'DeKalb Ave & Hudson Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 51},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 25,
#   'city': '',
#   'id': 325,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:03 PM',
#   'latitude': 40.73624527,
#   'location': '',
#   'longitude': -73.98473765,
#   'postalCode': '',
#   'stAddress1': 'E 19 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 19 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 25,
#   'availableDocks': 1,
#   'city': '',
#   'id': 326,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:51 PM',
#   'latitude': 40.72953837,
#   'location': '',
#   'longitude': -73.98426726,
#   'postalCode': '',
#   'stAddress1': 'E 11 St & 1 Ave',
#   'stAddress2': '',
#   'stationName': 'E 11 St & 1 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 21,
#   'availableDocks': 14,
#   'city': '',
#   'id': 327,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:36 PM',
#   'latitude': 40.7153379,
#   'location': '',
#   'longitude': -74.01658354,
#   'postalCode': '',
#   'stAddress1': 'Vesey Pl & River Terrace',
#   'stAddress2': '',
#   'stationName': 'Vesey Pl & River Terrace',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 14,
#   'availableDocks': 7,
#   'city': '',
#   'id': 328,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:12 PM',
#   'latitude': 40.72405549,
#   'location': '',
#   'longitude': -74.00965965,
#   'postalCode': '',
#   'stAddress1': 'Watts St & Greenwich St',
# ...
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 21,
#   'city': '',
#   'id': 3402,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:57 PM',
#   'latitude': 40.6902375,
#   'location': '',
#   'longitude': -73.99203074,
#   'postalCode': '',
#   'stAddress1': 'Court St & State St',
#   'stAddress2': '',
#   'stationName': 'Court St & State St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 18,
#   'availableDocks': 13,
#   'city': '',
#   'id': 3403,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:01 PM',
#   'latitude': 40.6705135,
#   'location': '',
#   'longitude': -73.98876585,
#   'postalCode': '',
#   'stAddress1': '4 Ave & 9 St',
#   'stAddress2': '',
#   'stationName': '4 Ave & 9 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 12,
#   'availableDocks': 15,
#   'city': '',
#   'id': 3404,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:47 PM',
#   'latitude': 40.6704922,
#   'location': '',
#   'longitude': -73.98541675,
#   'postalCode': '',
#   'stAddress1': '7 St & 5 Ave',
#   'stAddress2': '',
#   'stationName': '7 St & 5 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 11,
#   'city': '',
#   'id': 3405,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:27 PM',
#   'latitude': 40.6704836,
#   'location': '',
#   'longitude': -73.98208968,
#   'postalCode': '',
#   'stAddress1': '5 St & 6 Ave',
#   'stAddress2': '',
#   'stationName': '5 St & 6 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 15},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 9,
#   'city': '',
#   'id': 3407,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:50 PM',
#   'latitude': 40.67909799721684,
#   'location': '',
#   'longitude': -73.98765474557877,
#   'postalCode': '',
#   'stAddress1': 'Union St & Nevins St',
#   'stAddress2': '',
#   'stationName': 'Union St & Nevins St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 15},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 18,
#   'city': '',
#   'id': 3408,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:23 PM',
#   'latitude': 40.6881529,
#   'location': '',
#   'longitude': -73.99520919,
#   'postalCode': '',
#   'stAddress1': 'Congress St & Clinton St',
#   'stAddress2': '',
#   'stationName': 'Congress St & Clinton St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 29,
#   'city': '',
#   'id': 3409,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:34 PM',
#   'latitude': 40.6867443,
#   'location': '',
#   'longitude': -73.99063168,
#   'postalCode': '',
#   'stAddress1': 'Bergen St & Smith St',
#   'stAddress2': '',
#   'stationName': 'Bergen St & Smith St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 4,
#   'availableDocks': 27,
#   'city': '',
#   'id': 3410,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:18 PM',
#   'latitude': 40.6864442,
#   'location': '',
#   'longitude': -73.98759104,
#   'postalCode': '',
#   'stAddress1': 'Dean St & Hoyt St',
#   'stAddress2': '',
#   'stationName': 'Dean St & Hoyt St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 25,
#   'city': '',
#   'id': 3411,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:10 PM',
#   'latitude': 40.6849668,
#   'location': '',
#   'longitude': -73.98620772,
#   'postalCode': '',
#   'stAddress1': 'Bond St & Bergen St',
#   'stAddress2': '',
#   'stationName': 'Bond St & Bergen St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 10,
#   'city': '',
#   'id': 3412,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:17 PM',
#   'latitude': 40.6853761,
#   'location': '',
#   'longitude': -73.98302136,
#   'postalCode': '',
#   'stAddress1': 'Pacific St & Nevins St',
#   'stAddress2': '',
#   'stationName': 'Pacific St & Nevins St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 15},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 22,
#   'city': '',
#   'id': 3413,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:45 PM',
#   'latitude': 40.6827549,
#   'location': '',
#   'longitude': -73.98258555,
#   'postalCode': '',
#   'stAddress1': 'Wyckoff St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'Wyckoff St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 22},
#  {'altitude': '',
#   'availableBikes': 2,
#   'availableDocks': 31,
#   'city': '',
#   'id': 3414,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:56 PM',
#   'latitude': 40.680944723477296,
#   'location': '',
#   'longitude': -73.97567331790923,
#   'postalCode': '',
#   'stAddress1': 'Bergen St & Flatbush Ave',
#   'stAddress2': '',
#   'stationName': 'Bergen St & Flatbush Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 24,
#   'city': '',
#   'id': 3415,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:55 PM',
#   'latitude': 40.6793307,
#   'location': '',
#   'longitude': -73.97519523,
#   'postalCode': '',
#   'stAddress1': 'Prospect Pl & 6 Ave',
#   'stAddress2': '',
#   'stationName': 'Prospect Pl & 6 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 25},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 15,
#   'city': '',
#   'id': 3416,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:50 PM',
#   'latitude': 40.6776147,
#   'location': '',
#   'longitude': -73.97324283,
#   'postalCode': '',
#   'stAddress1': '7 Ave & Park Pl',
#   'stAddress2': '',
#   'stationName': '7 Ave & Park Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 17},
#  {'altitude': '',
#   'availableBikes': 18,
#   'availableDocks': 9,
#   'city': '',
#   'id': 3417,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:34 PM',
#   'latitude': 40.6795766,
#   'location': '',
#   'longitude': -73.97854971,
#   'postalCode': '',
#   'stAddress1': 'Baltic St & 5 Ave',
#   'stAddress2': '',
#   'stationName': 'Baltic St & 5 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 33,
#   'city': '',
#   'id': 3418,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:23 PM',
#   'latitude': 40.6750207,
#   'location': '',
#   'longitude': -73.97111473,
#   'postalCode': '',
#   'stAddress1': 'Plaza St West & Flatbush Ave',
#   'stAddress2': '',
#   'stationName': 'Plaza St West & Flatbush Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 7,
#   'availableDocks': 19,
#   'city': '',
#   'id': 3419,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:28 PM',
#   'latitude': 40.6792788,
#   'location': '',
#   'longitude': -73.98154004,
#   'postalCode': '',
#   'stAddress1': 'Douglass St & 4 Ave',
#   'stAddress2': '',
#   'stationName': 'Douglass St & 4 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 14,
#   'availableDocks': 7,
#   'city': '',
#   'id': 3420,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:11 PM',
#   'latitude': 40.6802133,
#   'location': '',
#   'longitude': -73.98432695,
#   'postalCode': '',
#   'stAddress1': 'Douglass St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'Douglass St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 21},
#  {'altitude': '',
#   'availableBikes': 10,
#   'availableDocks': 13,
#   'city': '',
#   'id': 3421,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:24 PM',
#   'latitude': 40.6843549,
#   'location': '',
#   'longitude': -73.98901629,
#   'postalCode': '',
#   'stAddress1': 'Hoyt St & Warren St',
#   'stAddress2': '',
#   'stationName': 'Hoyt St & Warren St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 23},
#  {'altitude': '',
#   'availableBikes': 2,
#   'availableDocks': 18,
#   'city': '',
#   'id': 3422,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:58 PM',
#   'latitude': 40.6859296,
#   'location': '',
#   'longitude': -74.00242364,
#   'postalCode': '',
#   'stAddress1': 'Columbia St & Degraw St',
#   'stAddress2': '',
#   'stationName': 'Columbia St & Degraw St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 21},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 16,
#   'city': '',
#   'id': 3423,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:18 PM',
#   'latitude': 40.6610633719006,
#   'location': '',
#   'longitude': -73.97945255041122,
#   'postalCode': '',
#   'stAddress1': 'West Drive & Prospect Park West',
#   'stAddress2': '',
#   'stationName': 'West Drive & Prospect Park West',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 29},
#  {'altitude': '',
#   'availableBikes': 9,
#   'availableDocks': 18,
#   'city': '',
#   'id': 3424,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:58 PM',
#   'latitude': 40.791976,
#   'location': '',
#   'longitude': -73.945993,
#   'postalCode': '',
#   'stAddress1': 'E 106 St & Lexington Ave',
#   'stAddress2': '',
#   'stationName': 'E 106 St & Lexington Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 27},
#  {'altitude': '',
#   'availableBikes': 14,
#   'availableDocks': 19,
#   'city': '',
#   'id': 3425,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:58 PM',
#   'latitude': 40.7892105,
#   'location': '',
#   'longitude': -73.94370784,
#   'postalCode': '',
#   'stAddress1': '2 Ave  & E 104 St',
#   'stAddress2': '',
#   'stationName': '2 Ave  & E 104 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 33},
#  {'altitude': '',
#   'availableBikes': 6,
#   'availableDocks': 31,
#   'city': '',
#   'id': 3427,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:25 PM',
#   'latitude': 40.72430527250332,
#   'location': '',
#   'longitude': -73.99600982666016,
#   'postalCode': '',
#   'stAddress1': 'Lafayette St & Jersey St',
#   'stAddress2': '',
#   'stationName': 'Lafayette St & Jersey St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 40},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 24,
#   'city': '',
#   'id': 3428,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:08 PM',
#   'latitude': 40.740983,
#   'location': '',
#   'longitude': -74.001702,
#   'postalCode': '',
#   'stAddress1': '8 Ave & W 16 St',
#   'stAddress2': '',
#   'stationName': '8 Ave & W 16 St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 25},
#  {'altitude': '',
#   'availableBikes': 3,
#   'availableDocks': 32,
#   'city': '',
#   'id': 3429,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#   'latitude': 40.68506807308177,
#   'location': '',
#   'longitude': -73.97790759801863,
#   'postalCode': '',
#   'stAddress1': 'Hanson Pl & Ashland Pl',
#   'stAddress2': '',
#   'stationName': 'Hanson Pl & Ashland Pl',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 39},
#  {'altitude': '',
#   'availableBikes': 7,
#   'availableDocks': 12,
#   'city': '',
#   'id': 3430,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:48 PM',
#   'latitude': 40.71907891179564,
#   'location': '',
#   'longitude': -73.94223690032959,
#   'postalCode': '',
#   'stAddress1': 'Richardson St & N Henry St',
#   'stAddress2': '',
#   'stationName': 'Richardson St & N Henry St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 19},
#  {'altitude': '',
#   'availableBikes': 13,
#   'availableDocks': 13,
#   'city': '',
#   'id': 3431,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:13 PM',
#   'latitude': 40.746524,
#   'location': '',
#   'longitude': -73.977885,
#   'postalCode': '',
#   'stAddress1': 'E 35 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 35 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 26},
#  {'altitude': '',
#   'availableBikes': 7,
#   'availableDocks': 28,
#   'city': '',
#   'id': 3434,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:12:15 PM',
#   'latitude': 40.79025417330419,
#   'location': '',
#   'longitude': -73.97718340158461,
#   'postalCode': '',
#   'stAddress1': 'W 88 St & West End Ave',
#   'stAddress2': '',
#   'stationName': 'W 88 St & West End Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 35},
#  {'altitude': '',
#   'availableBikes': 11,
#   'availableDocks': 29,
#   'city': '',
#   'id': 3435,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:04 PM',
#   'latitude': 40.718822,
#   'location': '',
#   'longitude': -73.99596,
#   'postalCode': '',
#   'stAddress1': 'Grand St & Elizabeth St',
#   'stAddress2': '',
#   'stationName': 'Grand St & Elizabeth St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 45},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 30,
#   'city': '',
#   'id': 3436,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:13:19 PM',
#   'latitude': 40.721319,
#   'location': '',
#   'longitude': -74.010065,
#   'postalCode': '',
#   'stAddress1': 'Greenwich St & Hubert St',
#   'stAddress2': '',
#   'stationName': 'Greenwich St & Hubert St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 0,
#   'city': '',
#   'id': 3437,
#   'landMark': '',
#   'lastCommunicationTime': '1969-12-31 07:00:00 PM',
#   'latitude': 40.79313480986663,
#   'location': '',
#   'longitude': -73.97700369358063,
#   'postalCode': '',
#   'stAddress1': 'Riverside Dr & W 91 St',
#   'stAddress2': '',
#   'stationName': 'Riverside Dr & W 91 St',
#   'statusKey': 3,
#   'statusValue': 'Not In Service',
#   'testStation': False,
#   'totalDocks': 0},
#  {'altitude': '',
#   'availableBikes': 5,
#   'availableDocks': 25,
#   'city': '',
#   'id': 3438,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:09:54 PM',
#   'latitude': 40.772248537721744,
#   'location': '',
#   'longitude': -73.95842134952545,
#   'postalCode': '',
#   'stAddress1': 'E 76 St & 3 Ave',
#   'stAddress2': '',
#   'stationName': 'E 76 St & 3 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 31},
#  {'altitude': '',
#   'availableBikes': 1,
#   'availableDocks': 41,
#   'city': '',
#   'id': 3440,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:11:46 PM',
#   'latitude': 40.692418292578466,
#   'location': '',
#   'longitude': -73.98949474096298,
#   'postalCode': '',
#   'stAddress1': 'Fulton St & Adams St',
#   'stAddress2': '',
#   'stationName': 'Fulton St & Adams St',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 43},
#  {'altitude': '',
#   'availableBikes': 0,
#   'availableDocks': 41,
#   'city': '',
#   'id': 3443,
#   'landMark': '',
#   'lastCommunicationTime': '2017-01-30 08:10:04 PM',
#   'latitude': 40.76132983124814,
#   'location': '',
#   'longitude': -73.97982001304626,
#   'postalCode': '',
#   'stAddress1': 'W 52 St & 6 Ave',
#   'stAddress2': '',
#   'stationName': 'W 52 St & 6 Ave',
#   'statusKey': 1,
#   'statusValue': 'In Service',
#   'testStation': False,
#   'totalDocks': 41}]

# %%
# obtain number of stations
len(r.json()['stationBeanList'])
# Out:
# 665

# %% [markdown]
# ### There are a total of 665 bike-sharing stations across NYC.

# %%
key_list = [] # unique list of keys for each station listing
for station in r.json()['stationBeanList']:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)
# provides the list values for each station

# %%
# remember that values for each station are a list and you can reference the elements like any other list using the index
r.json()['stationBeanList'][0] # will give data for each of the keys for station 1 (in zero position)
# Out:
# {'altitude': '',
#  'availableBikes': 5,
#  'availableDocks': 34,
#  'city': '',
#  'id': 72,
#  'landMark': '',
#  'lastCommunicationTime': '2017-01-30 08:13:32 PM',
#  'latitude': 40.76727216,
#  'location': '',
#  'longitude': -73.99392888,
#  'postalCode': '',
#  'stAddress1': 'W 52 St & 11 Ave',
#  'stAddress2': '',
#  'stationName': 'W 52 St & 11 Ave',
#  'statusKey': 1,
#  'statusValue': 'In Service',
#  'testStation': False,
#  'totalDocks': 39}

# %%
# getting data into a dataframe
from pandas.io.json import json_normalize
df = json_normalize(r.json()['stationBeanList'])

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df['availableBikes'].hist()
plt.show()

# %%
df['totalDocks'].hist()
plt.show()

# %%
df['availableDocks'].hist()
plt.show()

# %%
df['testStation'].hist()
plt.show()

# %% [markdown]
# ## Lesson Challenge

# %% [markdown]
# ### Are there any test stations?

# %%
import collections
freq_ts = print(collections.Counter(df['testStation']))

# %% [markdown]
# ### None of the 665 stations are test stations at the time of this analysis.

# %% [markdown]
# ### How many of the stations are in service?

# %%
freq_inserv = print(collections.Counter(df['statusValue']))

# %% [markdown]
# ### At the time of this analysis, there were 645 stations that were in service and 20 that were not active.

# %% [markdown]
# ### What is the mean and median number of bikes in both the active and non-active stations? What about when only the active stations are included?

# %%
mean_bikes1 = print(round(df['availableBikes'].mean(), 1))
med_bikes1 = print(df['availableBikes'].median())

# %%
u'id',
u'totalDocks',
u'city',
u'altitude',
u'stAddress2',
u'longitude',
u'postalCode',
u'testStation',
u'stAddress1',
u'stationName',
u'latitude',
u'location'

u'availableDocks',
u'statusKey',
u'statusValue',
u'lastCommunicationTime',
u'landMark'

# %%
import sqlite3 as lite

# %%
con = lite.connect('citi_bike.db')
cur = con.cursor()

# %%
with con:
    cur.execute('CREATE TABLE citibike_reference (id INT PRIMARY KEY, totalDocks INT, city TEXT, altitude INT, stAddress2 TEXT, longitude NUMERIC, postalCode TEXT, testStation TEXT, stAddress1 TEXT, stationName TEXT, landMark TEXT, latitude NUMERIC, location TEXT )')

# %%
sql = "INSERT INTO citibike_reference (id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)"

# %%
with con:
    for station in r.json()['stationBeanList']:
        #id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location)
        cur.execute(sql,(station['id'],station['totalDocks'],station['city'],station['altitude'],station['stAddress2'],station['longitude'],station['postalCode'],station['testStation'],station['stAddress1'],station['stationName'],station['landMark'],station['latitude'],station['location']))

# %%
#extract the column from the DataFrame and put them into a list
station_ids = df['id'].tolist()

# %%
#add the '_' to the station name and also add the data type for SQLite
station_ids = ['_' + str(x) + ' INT' for x in station_ids]

# %%
#create the table
#in this case, we're concatenating the string and joining all the station ids 
#(now with '_' and 'INT' added)
with con:
    cur.execute("CREATE TABLE available_bikes ( execution_time INT, " +  ", ".join(station_ids) + ");")

# %%
from dateutil.parser import parse

# %%
#take the string and parse it into a Python datetime object
exec_time = parse(r.json()['executionTime'])

# %%
with con:
    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', (exec_time.strftime('%s'),))

# %%
id_bikes = collections.defaultdict(int) #defaultdict to store available bikes by station

# %%
#loop through the stations in the station list
for station in r.json()['stationBeanList']:
    id_bikes[station['id']] = station['availableBikes']

# %%
#iterate through the defaultdict to update the values in the database
with con:
    for k, v in id_bikes.items():
        cur.execute("UPDATE available_bikes SET _" + str(k) + " = " + str(v) + " WHERE execution_time = " + exec_time.strftime('%s') + ";")

# %%
import time

# %%
con = lite.connect('citi_bike.db')
cur = con.cursor()

# %%
for i in range(60):
    r = requests.get('http://www.citibikenyc.com/stations/json')
    exec_time = parse(r.json()['executionTime']).strftime("%s")

    cur.execute('INSERT INTO available_bikes (execution_time) VALUES (?)', (exec_time,))

    for station in r.json()['stationBeanList']:
        cur.execute("UPDATE available_bikes SET _%d = %d WHERE execution_time = %s" % (station['id'], station['availableBikes'], exec_time))
    con.commit()

    time.sleep(60)

con.close()

# %%
con=lite.connect('citi_bike.db')
cur = con.cursor

# %%
df = pd.read_sql_query('select * from available_bikes order by execution_time', con, index_col='execution_time')

# %%
hour_change = collections.defaultdict(int)
for col in df.columns:
    station_vals = df[col].tolist()
    station_id = col[1:] #trim the "_"
    station_change = 0
    for k,v in enumerate(station_vals):
        if k < len(station_vals) - 1:
            station_change += abs(station_vals[k] - station_vals[k+1])
    hour_change[int(station_id)] = station_change #convert the station id back to integer

# %%
def keywithmaxval(d):
    """Find the key with the greatest value"""
    return max(d, key=lambda k: d[k])

# %%
# assign the max key to max_station
max_station = keywithmaxval(hour_change)

# %%
from datetime import date

con = lite.connect('citi_bike.db')
cur = con.cursor()
cur.execute("SELECT id, stationname, latitude, longitude FROM citibike_reference WHERE id = ?", (max_station,))
data = cur.fetchone()
print("The most active station is station id %s at %s latitude: %s longitude: %s " % data)
print("With %d bicycles coming and going in the hour between %s and %s" % (
    hour_change[max_station],
    date.fromtimestamp(int(df.index[0])).strftime('%Y-%m-%dT%H:%M:%S'),
    date.fromtimestamp(int(df.index[-1])).strftime('%Y-%m-%dT%H:%M:%S'),
))

# %%
import matplotlib.pyplot as plt
plt.bar(hour_change.keys(), hour_change.values())
plt.show()
